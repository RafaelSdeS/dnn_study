# %% [markdown]
# # Sincronização W&B e Análise de Resultados — AlexNet QAT
#
# Notebook de análise: sincroniza os logs offline do Weights & Biases, carrega a tabela final de comparação e os históricos de treino (FP32 e QAT), e gera os gráficos de curvas de treino e Accuracy vs Model Size.

# %% [markdown]
# ## 1. Sincronizar logs locais do W&B

# %%
import wandb
wandb.login()
# Sincroniza os metadados contidos na pasta local ./wandb para o servidor do W&B.
# Como o notebook principal rodou com "offline=True", esse passo é obrigatório.

print("Sincronizando logs locais com o servidor do Weights & Biases...")
# !wandb sync --sync-all
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/rafael/.netrc.
# wandb: Currently logged in as: rafesilvadesouza (rafesilvadesouza-ufrgs) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Sincronizando logs locais com o servidor do Weights & Biases...
# Find logs at: /home/rafael/Documents/alexnet_rafael/wandb/debug-cli.rafael.log
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/66lm3tv4 ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/575umqu9 ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/swj2o8y6 ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/jf3ky2i6 ... done.
# done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/fasbyr2n ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/d40im3gj ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/sxv6v3pf ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/xlt1xtdj ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/u1c2pwdx ... done.
# done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/8rtouv6b ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/5ct2ewqz ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/baqg49ev ... done.
# done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/6wggk58v ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/vvgfkq4m ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/aug6auzb ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/0c9thtm7 ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/rbd118ae ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/z1e9efze ... done.
# done.
# done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/5by8l8mj ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/myclysfo ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/3s8mm48v ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/dhh1n77x ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/hdyk3j8w ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/23n4xsqi ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/xjl7j8oh ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/y8069jrj ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/mw5bmu61 ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/9dmci6td ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/wahogsyk ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/5jesy7sp ... done.
# Syncing: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet/runs/y6fz1rxe ... done.

# %% [markdown]
# ## 2. Configuração

# %%
import os
import json
import wandb
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import IFrame

# Caso ainda não tenha feito a autenticação na sua máquina atual,
# descomente a linha abaixo para inserir o seu token de API:
# !wandb login

WANDB_USERNAME = "rafesilvadesouza-ufrgs"
PROJECT_NAME = "tiny-imagenet"

# IMPORTANTE: precisa ser EXATAMENTE o mesmo save_dir usado no notebook de treino
from pathlib import Path
project_root = Path.cwd().parent
SAVE_DIR = str(project_root / "results" / "alexnet_qat")

# %% [markdown]
# ## 3. Tabela final de comparação

# %%
csv_path = os.path.join(SAVE_DIR, "tables", "final_comparison.csv")

if os.path.exists(csv_path):
    print("Tabela Final de Comparações Encontrada localmente:")
    df_results = pd.read_csv(csv_path)
    display(df_results)
else:
    print(f"Aviso: O arquivo {csv_path} ainda não foi gerado pelo notebook de treino.")
# Out:
# Tabela Final de Comparações Encontrada localmente:
#                        model precision  top1_%  top5_%      loss   params_M  \
# 0               AlexNet_FP32      FP32   28.43   55.01  3.569552  57.823240
# 1          AlexNetSmall_FP32      FP32    8.56   25.72  4.555502   1.602376
# 2            AlexNet3x3_FP32      FP32    8.25   24.38  4.578262  57.605128
# 3          alexnet_fp32_INT8      INT8   30.06   56.63  3.490038  57.823240
# 4           alexnet_3x3_INT8      INT8    9.57   27.53  4.483409  57.605128
# 5  alexnet_small_kernel_INT8      INT8    8.95   27.19  4.518156   1.602376
#
#       size_MB
# 0  220.584150
# 1    6.117510
# 2  219.752039
# 3   55.332716
# 4   55.124596
# 5    1.561041

# %% [markdown]
# ## 4. Painel interativo do W&B (embed)

# %%
# Renderiza o workspace completo do W&B direto na saída da célula do Jupyter.
# Permite sobrepor e comparar as curvas (loss/accuracy) das execuções simultaneamente.
url_workspace = f"https://wandb.ai/{WANDB_USERNAME}/{PROJECT_NAME}?workspace=user-{WANDB_USERNAME}"
print(f"Abra o painel interativo no navegador: {url_workspace}")
# Out:
# Abra o painel interativo no navegador: https://wandb.ai/rafesilvadesouza-ufrgs/tiny-imagenet?workspace=user-rafesilvadesouza-ufrgs

# %% [markdown]
# ## 5. Carregar resumo do experimento

# %%
summary_path = os.path.join(SAVE_DIR, "summaries", "experiment_summary.json")
summary_data = None

if os.path.exists(summary_path):
    with open(summary_path, "r") as f:
        summary_data = json.load(f)
    print("Dados locais carregados com sucesso!")
else:
    print(f"Aviso: {summary_path} não encontrado. Rode o notebook de treino primeiro.")

# Model keys must match MODEL_REGISTRY names from the training notebook.
FP32_MODELS = [
    ("alexnet_fp32", "AlexNet Pretrained"),
    ("alexnet_3x3", "AlexNet 3x3"),
    ("alexnet_small_kernel", "AlexNet Small Kernel"),
]

QAT_MODELS = [
    ("alexnet_fp32", "QAT AlexNet"),
    ("alexnet_3x3", "QAT AlexNet 3x3"),
    ("alexnet_small_kernel", "QAT AlexNet Small"),
]
# Out:
# Dados locais carregados com sucesso!

# %% [markdown]
# ## 6. Função auxiliar de plotagem

# %%
def plot_training_curves(results_dict, model_list, title_prefix):
    """Plot val_loss, val_acc, train_acc, epoch_time for a set of models.

    `results_dict` is summary_data["fp32_training_results"] or
    summary_data["qat_training_results"]. Missing keys/metrics are skipped
    with a printed warning instead of failing silently.
    """
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))
    panels = [
        (axes[0, 0], "val_loss", f"{title_prefix} - Validation Loss", "Loss"),
        (axes[0, 1], "val_acc", f"{title_prefix} - Validation Accuracy", "Accuracy (%)"),
        (axes[1, 0], "train_acc", f"{title_prefix} - Training Accuracy", "Accuracy (%)"),
        (axes[1, 1], "epoch_time", f"{title_prefix} - Epoch Time", "Seconds"),
    ]

    for ax, metric_key, plot_title, ylabel in panels:
        for key, label in model_list:
            result = results_dict.get(key)
            if not result:
                print(f"  [skip] '{key}' not found in results (expected for '{label}')")
                continue

            history = result.get("history", {})
            if metric_key not in history:
                print(f"  [skip] '{metric_key}' missing from history for '{key}'")
                continue

            epochs = range(1, len(history[metric_key]) + 1)
            ax.plot(epochs, history[metric_key], marker="o", label=label)

        ax.set_title(plot_title)
        ax.set_xlabel("Epoch")
        ax.set_ylabel(ylabel)
        ax.grid(True, alpha=0.3)
        ax.legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 7. Curvas de treino — FP32

# %%
if summary_data is not None:
    print("Plotando curvas FP32...")
    plot_training_curves(
        summary_data.get("fp32_training_results", {}),
        FP32_MODELS,
        title_prefix="FP32",
    )
else:
    print("summary_data não carregado — pulando gráficos FP32.")
# Out:
# Plotando curvas FP32...

# %% [markdown]
# ## 8. Curvas de treino — QAT / INT8

# %%
if summary_data is not None:
    print("Plotando curvas QAT...")
    plot_training_curves(
        summary_data.get("qat_training_results", {}),
        QAT_MODELS,
        title_prefix="QAT",
    )
else:
    print("summary_data não carregado — pulando gráficos QAT.")
# Out:
# Plotando curvas QAT...

# %% [markdown]
# ## 9. Accuracy vs Tamanho do Modelo (FP32 vs INT8)

# %%
if os.path.exists(csv_path):
    df = pd.read_csv(csv_path)

    plt.figure(figsize=(10, 6))

    markers = {
        "FP32": "o",
        "INT8": "s",
    }

    pairs = [
        ("AlexNet_FP32", "AlexNet_INT8"),
        ("AlexNet3x3_FP32", "AlexNet3x3_INT8"),
        ("AlexNetSmall_FP32", "AlexNetSmall_INT8"),
    ]

    for fp32_name, int8_name in pairs:
        fp32_rows = df[df["model"] == fp32_name]
        int8_rows = df[df["model"] == int8_name]

        if fp32_rows.empty or int8_rows.empty:
            print(f"  [skip] pair ({fp32_name}, {int8_name}) not found in final_comparison.csv")
            continue

        fp32 = fp32_rows.iloc[0]
        int8 = int8_rows.iloc[0]

        plt.plot(
            [fp32["size_MB"], int8["size_MB"]],
            [fp32["top1_%"], int8["top1_%"]],
            linewidth=1,
        )

    for _, row in df.iterrows():
        plt.scatter(
            row["size_MB"],
            row["top1_%"],
            marker=markers.get(row["precision"], "x"),
            s=120,
            label=row["precision"],
        )

        plt.annotate(
            row["model"],
            (row["size_MB"], row["top1_%"]),
            xytext=(5, 5),
            textcoords="offset points",
        )

    # legenda sem duplicatas
    handles, labels = plt.gca().get_legend_handles_labels()
    unique = dict(zip(labels, handles))
    plt.legend(unique.values(), unique.keys())

    plt.xlabel("Model Size (MB)")
    plt.ylabel("Top-1 Accuracy (%)")
    plt.title("Accuracy vs Model Size")
    plt.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()
else:
    print(f"Aviso: {csv_path} não encontrado — pulando gráfico de Accuracy vs Size.")
# Out:
#   [skip] pair (AlexNet_FP32, AlexNet_INT8) not found in final_comparison.csv
#   [skip] pair (AlexNet3x3_FP32, AlexNet3x3_INT8) not found in final_comparison.csv
#   [skip] pair (AlexNetSmall_FP32, AlexNetSmall_INT8) not found in final_comparison.csv
