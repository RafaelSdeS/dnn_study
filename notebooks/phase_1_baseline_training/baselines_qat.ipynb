# %% [markdown]
# # Baseline CNNs on Tiny-ImageNet — FP32 & QAT (INT8)
#
# **Author:** Rafael
# **Dataset:** Tiny-ImageNet-200 (200 classes, 64×64 RGB)
# **Goal:** Train and compare the 4 Phase 1 reference architectures in FP32, then apply
# Quantization-Aware Training (QAT) to the QAT-compatible models to obtain INT8 versions.
#
# | Model | QAT | Notes |
# |---|---|---|
# | AlexNetTV | ✓ | Pretrained torchvision AlexNet, Conv-ReLU fused |
# | VGGStyleCNN | ✓ | From-scratch, stacked 3×3, Conv-BN-ReLU stages |
# | ResNet18TV | ✗ | Pretrained ResNet-18; residual adds lack FloatFunctional → FP32 only |
# | MobileNetV2TV | ✗ | Pretrained MobileNetV2; inverted residual adds → FP32 only |
#
# ## Notebook layout
#
# 1. Imports & reproducibility
# 2. Dataset & loaders
# 3. Model shape check
# 4. Model registration (fuse maps)
# 5. FP32 training
# 6. QAT training (AlexNetTV, VGGStyleCNN)
# 7. INT8 conversion & CPU evaluation
# 8. FP32 evaluation (reload best checkpoints)
# 9. Final comparison table
# 10. Persist experiment summary

# %% [markdown]
# ## 1. Imports & reproducibility

# %%
import json
import os
import random
import sys
from dataclasses import asdict, replace
from pathlib import Path

import numpy as np
import torch
import torch.nn as nn
import torchinfo
import wandb

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

from ml import (
    DataConfig, TrainerConfig, QATConfig,
    create_imagenet_loaders,
    MODEL_REGISTRY, register_model,
    Trainer, make_qat_callback,
    build_qat, build_comparison_table,
    load_best_model, convert_to_int8,
    auto_resume_path, compress_checkpoint,
    create_results_summary, disk_mb, gzip_mb,
    compute_flops, make_run_summary,
)
from configs.loader import load_config

from models import (
    AlexNetTV,
    VGGStyleCNN,
    ResNet18TV,
    MobileNetV2TV,
)

torch.backends.quantized.engine = "fbgemm"

# %%
SEED = 42
random.seed(SEED); np.random.seed(SEED)
torch.manual_seed(SEED); torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.deterministic = True
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

SAVE_DIR    = project_root / "checkpoints" / "baselines_qat_phase1"
RESULTS_DIR = project_root / "results" / "baselines_qat_phase1"
SAVE_DIR.mkdir(parents=True, exist_ok=True)
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

data_cfg = DataConfig(**load_config("data.yaml"))
data_cfg.seed = SEED
fp32_cfg = TrainerConfig(**load_config("training.yaml"))
qat_cfg  = QATConfig(**load_config("qat.yaml"))
print(device)
# Out:
# cuda

# %% [markdown]
# ## 2. Dataset & loaders

# %%
import kagglehub

dataset_path = kagglehub.dataset_download("akash2sharma/tiny-imagenet")
train_path = os.path.join(dataset_path, "tiny-imagenet-200", "train")
data_cfg.dataset_path = train_path
print("Tiny-ImageNet train path:", train_path)

train_ds, val_ds, train_loader, val_loader = create_imagenet_loaders(data_cfg)

print(f"Train samples: {len(train_ds):,}")
print(f"Val   samples: {len(val_ds):,}")
print(f"Classes:       {data_cfg.num_classes}")
print(f"Batches/epoch: train={len(train_loader)}, val={len(val_loader)}")
# Out:
# Tiny-ImageNet train path: /home/rafael/.cache/kagglehub/datasets/akash2sharma/tiny-imagenet/versions/1/tiny-imagenet-200/train
# Train samples: 90,000
# Val   samples: 10,000
# Classes:       200
# Batches/epoch: train=1406, val=157

# %% [markdown]
# ## 3. Model shape check

# %%
x = torch.randn(2, 3, data_cfg.img_size, data_cfg.img_size)
for label, ctor in [
    ("AlexNetTV",    AlexNetTV),
    ("VGGStyleCNN",  VGGStyleCNN),
    ("ResNet18TV",   ResNet18TV),
    ("MobileNetV2TV",MobileNetV2TV),
]:
    m = ctor().eval()
    with torch.no_grad():
        y = m(x)
    assert y.shape == (2, data_cfg.num_classes), f"{label}: unexpected shape {y.shape}"
    info = torchinfo.summary(m, input_size=(1, 3, data_cfg.img_size, data_cfg.img_size), verbose=0)
    print(f"{label:20s} OK -> {tuple(y.shape)}, params={info.total_params/1e6:.2f}M")
# Out:
# AlexNetTV            OK -> (2, 200), params=57.82M
# VGGStyleCNN          OK -> (2, 200), params=2.41M
# ResNet18TV           OK -> (2, 200), params=11.28M
# MobileNetV2TV        OK -> (2, 200), params=2.48M

# %% [markdown]
# ## 4. Model registration
#
# Fuse maps are index-based paths inside `features` for flat-Sequential models.
# `ResNet18TV` and `MobileNetV2TV` are registered but excluded from QAT — their residual
# adds use plain `+` / inverted bottleneck without `FloatFunctional`, so fake-quant observers
# cannot intercept them.

# %%
# Conv-ReLU (torchvision AlexNet has no BN in features)
FUSE_MAP_ALEXNET_TV = [["0","1"],["3","4"],["6","7"],["8","9"],["10","11"]]

# Conv-BN-ReLU, two per VGG stage (5 stages × 2 = 10 groups)
FUSE_MAP_VGG = [
    ["0","1","2"],["3","4","5"],
    ["7","8","9"],["10","11","12"],
    ["14","15","16"],["17","18","19"],
    ["21","22","23"],["24","25","26"],
    ["28","29","30"],["31","32","33"],
]

MODEL_REGISTRY.clear()
register_model("alexnet_tv",  AlexNetTV,     fuse_map=FUSE_MAP_ALEXNET_TV, fuse_root_attr="features", lr=3e-4)
register_model("vgg_style",   VGGStyleCNN, fuse_map=FUSE_MAP_VGG,        fuse_root_attr="features", lr=1e-3)
register_model("resnet18_tv", ResNet18TV,    fuse_map=[],                                             lr=1e-4)  # ponytail: QAT skipped — vanilla residual adds
register_model("mobilenetv2", MobileNetV2TV, fuse_map=[],                                             lr=1e-4)  # ponytail: QAT skipped — inverted residual adds

print("Registered:", list(MODEL_REGISTRY))
# Out:
# Registered: ['alexnet_tv', 'vgg_style', 'resnet18_tv', 'mobilenetv2']

# %% [markdown]
# ## 5. FP32 training

# %%
fp32_training_results = {}

for name, spec in MODEL_REGISTRY.items():
    # Auto-detect resume checkpoint
    resume_from = auto_resume_path(SAVE_DIR, name)
    
    # If best already exists and no resume checkpoint, skip
    if (SAVE_DIR / f"{name}_best.pth").exists() and not resume_from:
        print(f"Skipping FP32 training for {name} (checkpoint found).")
        continue
    
    # Restore W&B run if resuming
    run_id = None
    if resume_from:
        meta_path = SAVE_DIR / f"{name}_meta.json"
        if meta_path.exists():
            run_id = json.loads(meta_path.read_text()).get("wandb_run_id")
    
    model_cfg = replace(fp32_cfg, lr=spec.get("lr", fp32_cfg.lr))
    print("=" * 72)
    print(f"Training: {name}  lr={model_cfg.lr}  epochs={model_cfg.epochs}")
    if resume_from:
        print(f"(Resuming from checkpoint)")
    print("=" * 72)

    model = spec["ctor"]().to(device)

    run = wandb.init(
        project="alexnet-baselines",
        group="fp32-baselines",
        name=f"{name}_fp32",
        id=run_id,
        resume="allow" if run_id else None,
        config={**asdict(model_cfg), "arch": name, "phase": "fp32",
                "num_classes": data_cfg.num_classes, "img_size": data_cfg.img_size,
                "dataset": "tiny-imagenet-200"},
        tags=["phase1", "baselines", "tiny-imagenet", "fp32"],
        mode="offline",
    )

    trainer = Trainer(
        model, train_loader, val_loader, model_cfg,
        device, SAVE_DIR, name, num_classes=data_cfg.num_classes,
        wandb_run=run,
        log_file=SAVE_DIR / f"{name}.log",
    )
    results = trainer.fit(resume_from=resume_from)
    wandb.finish()

    fp32_training_results[name] = results

    del model
    torch.cuda.empty_cache()

print("\nFP32 training complete.")
# Out:
# ========================================================================
# Training: alexnet_tv  lr=0.0003  epochs=100
# ========================================================================
# Tracking run with wandb version 0.28.0
# W&B syncing is set to <code>`offline`<code> in this directory. Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.<br>Run data is saved locally in <code>/home/rafael/Documents/alexnet_rafael/notebooks/wandb/offline-run-20260630_094445-ibohabrt</code><br>View this run in the terminal with <code>`wandb leet`<code>
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.06it/s, acc=7.98%, loss=4.6392]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 119.60it/s, loss=4.2379, top1=14.16%, top5=35.13%]
# wandb: WARNING Saving files without folders. If you want to preserve subdirectories pass base_path to wandb.save, i.e. wandb.save("/mnt/folder/file.h5", base_path="/mnt")
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# Epoch   1/100 | train_loss=4.6392 train_acc=7.98% | val_loss=4.2379 val_acc=14.16% val_top5=35.13% | lr=3.00e-04 peak_mem=1410MB time=48.1s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.30it/s, acc=12.08%, loss=4.3729]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 134.79it/s, loss=4.0135, top1=17.94%, top5=42.37%]
# Epoch   2/100 | train_loss=4.3729 train_acc=12.08% | val_loss=4.0135 val_acc=17.94% val_top5=42.37% | lr=3.00e-04 peak_mem=1410MB time=47.6s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.28it/s, acc=13.76%, loss=4.2876]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 139.09it/s, loss=3.9861, top1=19.05%, top5=43.85%]
# Epoch   3/100 | train_loss=4.2876 train_acc=13.76% | val_loss=3.9861 val_acc=19.05% val_top5=43.85% | lr=2.99e-04 peak_mem=1410MB time=47.6s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.25it/s, acc=15.05%, loss=4.2306]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 122.83it/s, loss=3.9003, top1=21.37%, top5=45.67%]
# Epoch   4/100 | train_loss=4.2306 train_acc=15.05% | val_loss=3.9003 val_acc=21.37% val_top5=45.67% | lr=2.99e-04 peak_mem=1410MB time=47.8s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.28it/s, acc=15.80%, loss=4.1904]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 149.12it/s, loss=3.9533, top1=19.90%, top5=44.30%]
# Epoch   5/100 | train_loss=4.1904 train_acc=15.80% | val_loss=3.9533 val_acc=19.90% val_top5=44.30% | lr=2.98e-04 peak_mem=1410MB time=47.5s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.16it/s, acc=16.40%, loss=4.1629]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 139.67it/s, loss=3.9065, top1=20.78%, top5=45.66%]
# Epoch   6/100 | train_loss=4.1629 train_acc=16.40% | val_loss=3.9065 val_acc=20.78% val_top5=45.66% | lr=2.97e-04 peak_mem=1410MB time=47.8s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.18it/s, acc=16.65%, loss=4.1418]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 145.45it/s, loss=3.8501, top1=22.32%, top5=47.56%]
# Epoch   7/100 | train_loss=4.1418 train_acc=16.65% | val_loss=3.8501 val_acc=22.32% val_top5=47.56% | lr=2.96e-04 peak_mem=1410MB time=47.7s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.23it/s, acc=17.11%, loss=4.1200]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 147.55it/s, loss=3.8451, top1=22.11%, top5=47.18%]
# Epoch   8/100 | train_loss=4.1200 train_acc=17.11% | val_loss=3.8451 val_acc=22.11% val_top5=47.18% | lr=2.95e-04 peak_mem=1410MB time=47.6s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.03it/s, acc=17.54%, loss=4.1019]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 149.15it/s, loss=3.8371, top1=22.75%, top5=47.65%]
# Epoch   9/100 | train_loss=4.1019 train_acc=17.54% | val_loss=3.8371 val_acc=22.75% val_top5=47.65% | lr=2.94e-04 peak_mem=1410MB time=47.9s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.15it/s, acc=17.50%, loss=4.0938]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 142.47it/s, loss=3.8972, top1=21.57%, top5=45.69%]
# Epoch  10/100 | train_loss=4.0938 train_acc=17.50% | val_loss=3.8972 val_acc=21.57% val_top5=45.69% | lr=2.93e-04 peak_mem=1410MB time=47.8s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.21it/s, acc=18.02%, loss=4.0844]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 140.96it/s, loss=3.8356, top1=23.12%, top5=47.68%]
# Epoch  11/100 | train_loss=4.0844 train_acc=18.02% | val_loss=3.8356 val_acc=23.12% val_top5=47.68% | lr=2.91e-04 peak_mem=1410MB time=47.7s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.21it/s, acc=18.28%, loss=4.0719]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 145.22it/s, loss=3.8667, top1=22.66%, top5=46.79%]
# Epoch  12/100 | train_loss=4.0719 train_acc=18.28% | val_loss=3.8667 val_acc=22.66% val_top5=46.79% | lr=2.89e-04 peak_mem=1410MB time=47.7s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.13it/s, acc=18.55%, loss=4.0665]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 139.02it/s, loss=3.8637, top1=22.67%, top5=46.69%]
# Epoch  13/100 | train_loss=4.0665 train_acc=18.55% | val_loss=3.8637 val_acc=22.67% val_top5=46.69% | lr=2.88e-04 peak_mem=1410MB time=47.8s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.19it/s, acc=18.63%, loss=4.0582]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 148.41it/s, loss=3.8191, top1=23.95%, top5=48.51%]
# Epoch  14/100 | train_loss=4.0582 train_acc=18.63% | val_loss=3.8191 val_acc=23.95% val_top5=48.51% | lr=2.86e-04 peak_mem=1410MB time=47.7s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.16it/s, acc=18.85%, loss=4.0467]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 137.85it/s, loss=3.8688, top1=22.51%, top5=46.66%]
# Epoch  15/100 | train_loss=4.0467 train_acc=18.85% | val_loss=3.8688 val_acc=22.51% val_top5=46.66% | lr=2.84e-04 peak_mem=1410MB time=47.8s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.11it/s, acc=18.95%, loss=4.0399]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 125.85it/s, loss=3.8432, top1=23.57%, top5=47.62%]
# Epoch  16/100 | train_loss=4.0399 train_acc=18.95% | val_loss=3.8432 val_acc=23.57% val_top5=47.62% | lr=2.81e-04 peak_mem=1410MB time=48.0s
# Training: 100%|██████████| 1406/1406 [00:47<00:00, 29.69it/s, acc=19.00%, loss=4.0355]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 149.79it/s, loss=3.8075, top1=23.40%, top5=48.10%]
# Epoch  17/100 | train_loss=4.0355 train_acc=19.00% | val_loss=3.8075 val_acc=23.40% val_top5=48.10% | lr=2.79e-04 peak_mem=1410MB time=48.4s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.05it/s, acc=19.25%, loss=4.0289]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 132.64it/s, loss=3.7925, top1=23.56%, top5=48.61%]
# Epoch  18/100 | train_loss=4.0289 train_acc=19.25% | val_loss=3.7925 val_acc=23.56% val_top5=48.61% | lr=2.77e-04 peak_mem=1410MB time=48.0s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.07it/s, acc=19.55%, loss=4.0228]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 148.09it/s, loss=3.7458, top1=24.42%, top5=49.56%]
# Epoch  19/100 | train_loss=4.0228 train_acc=19.55% | val_loss=3.7458 val_acc=24.42% val_top5=49.56% | lr=2.74e-04 peak_mem=1410MB time=47.9s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.13it/s, acc=19.41%, loss=4.0099]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 139.30it/s, loss=3.8042, top1=24.05%, top5=47.98%]
# Epoch  20/100 | train_loss=4.0099 train_acc=19.41% | val_loss=3.8042 val_acc=24.05% val_top5=47.98% | lr=2.71e-04 peak_mem=1410MB time=47.8s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.16it/s, acc=19.91%, loss=3.9997]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 131.30it/s, loss=3.7533, top1=24.97%, top5=49.77%]
# Epoch  21/100 | train_loss=3.9997 train_acc=19.91% | val_loss=3.7533 val_acc=24.97% val_top5=49.77% | lr=2.69e-04 peak_mem=1410MB time=47.9s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.17it/s, acc=20.09%, loss=3.9931]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 138.49it/s, loss=3.8083, top1=24.13%, top5=48.61%]
# Epoch  22/100 | train_loss=3.9931 train_acc=20.09% | val_loss=3.8083 val_acc=24.13% val_top5=48.61% | lr=2.66e-04 peak_mem=1410MB time=47.8s
# Training: 100%|██████████| 1406/1406 [00:47<00:00, 29.87it/s, acc=20.12%, loss=3.9885]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 143.31it/s, loss=3.7874, top1=24.77%, top5=48.81%]
# Epoch  23/100 | train_loss=3.9885 train_acc=20.12% | val_loss=3.7874 val_acc=24.77% val_top5=48.81% | lr=2.63e-04 peak_mem=1410MB time=48.2s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.11it/s, acc=20.54%, loss=3.9756]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 122.28it/s, loss=3.7319, top1=25.65%, top5=50.17%]
# Epoch  24/100 | train_loss=3.9756 train_acc=20.54% | val_loss=3.7319 val_acc=25.65% val_top5=50.17% | lr=2.59e-04 peak_mem=1410MB time=48.0s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.07it/s, acc=20.47%, loss=3.9616]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 150.21it/s, loss=3.7613, top1=24.76%, top5=49.57%]
# Epoch  25/100 | train_loss=3.9616 train_acc=20.47% | val_loss=3.7613 val_acc=24.76% val_top5=49.57% | lr=2.56e-04 peak_mem=1410MB time=47.8s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.15it/s, acc=20.66%, loss=3.9555]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 135.79it/s, loss=3.7210, top1=25.91%, top5=50.59%]
# Epoch  26/100 | train_loss=3.9555 train_acc=20.66% | val_loss=3.7210 val_acc=25.91% val_top5=50.59% | lr=2.53e-04 peak_mem=1410MB time=47.8s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.18it/s, acc=20.99%, loss=3.9515]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 130.02it/s, loss=3.7820, top1=24.66%, top5=48.33%]
# Epoch  27/100 | train_loss=3.9515 train_acc=20.99% | val_loss=3.7820 val_acc=24.66% val_top5=48.33% | lr=2.49e-04 peak_mem=1410MB time=47.8s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.23it/s, acc=21.21%, loss=3.9352]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 135.72it/s, loss=3.7069, top1=25.19%, top5=50.30%]
# Epoch  28/100 | train_loss=3.9352 train_acc=21.21% | val_loss=3.7069 val_acc=25.19% val_top5=50.30% | lr=2.46e-04 peak_mem=1410MB time=47.7s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.15it/s, acc=21.40%, loss=3.9327]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 113.84it/s, loss=3.7132, top1=25.95%, top5=50.78%]
# Epoch  29/100 | train_loss=3.9327 train_acc=21.40% | val_loss=3.7132 val_acc=25.95% val_top5=50.78% | lr=2.42e-04 peak_mem=1410MB time=48.1s
# Training: 100%|██████████| 1406/1406 [00:47<00:00, 29.91it/s, acc=21.71%, loss=3.9172]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 137.90it/s, loss=3.7344, top1=25.26%, top5=50.39%]
# Epoch  30/100 | train_loss=3.9172 train_acc=21.71% | val_loss=3.7344 val_acc=25.26% val_top5=50.39% | lr=2.38e-04 peak_mem=1410MB time=48.2s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.03it/s, acc=21.69%, loss=3.9056]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 127.67it/s, loss=3.6849, top1=26.35%, top5=51.40%]
# Epoch  31/100 | train_loss=3.9056 train_acc=21.69% | val_loss=3.6849 val_acc=26.35% val_top5=51.40% | lr=2.34e-04 peak_mem=1410MB time=48.1s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.02it/s, acc=22.06%, loss=3.8993]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 127.10it/s, loss=3.7167, top1=25.84%, top5=50.37%]
# Epoch  32/100 | train_loss=3.8993 train_acc=22.06% | val_loss=3.7167 val_acc=25.84% val_top5=50.37% | lr=2.30e-04 peak_mem=1410MB time=48.1s
# Training: 100%|██████████| 1406/1406 [00:47<00:00, 29.62it/s, acc=22.17%, loss=3.8849]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 119.88it/s, loss=3.7023, top1=26.62%, top5=50.97%]
# Epoch  33/100 | train_loss=3.8849 train_acc=22.17% | val_loss=3.7023 val_acc=26.62% val_top5=50.97% | lr=2.26e-04 peak_mem=1410MB time=48.8s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.02it/s, acc=22.58%, loss=3.8768]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 131.29it/s, loss=3.7008, top1=26.42%, top5=50.88%]
# Epoch  34/100 | train_loss=3.8768 train_acc=22.58% | val_loss=3.7008 val_acc=26.42% val_top5=50.88% | lr=2.22e-04 peak_mem=1410MB time=48.1s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.01it/s, acc=22.68%, loss=3.8714]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 134.34it/s, loss=3.6543, top1=27.16%, top5=52.18%]
# Epoch  35/100 | train_loss=3.8714 train_acc=22.68% | val_loss=3.6543 val_acc=27.16% val_top5=52.18% | lr=2.18e-04 peak_mem=1410MB time=48.1s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.01it/s, acc=22.64%, loss=3.8591]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 130.59it/s, loss=3.6859, top1=26.38%, top5=51.27%]
# Epoch  36/100 | train_loss=3.8591 train_acc=22.64% | val_loss=3.6859 val_acc=26.38% val_top5=51.27% | lr=2.14e-04 peak_mem=1410MB time=48.1s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.00it/s, acc=22.82%, loss=3.8572]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 131.00it/s, loss=3.6414, top1=27.13%, top5=52.49%]
# Epoch  37/100 | train_loss=3.8572 train_acc=22.82% | val_loss=3.6414 val_acc=27.13% val_top5=52.49% | lr=2.10e-04 peak_mem=1410MB time=48.1s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.09it/s, acc=23.56%, loss=3.8364]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 135.29it/s, loss=3.6502, top1=27.49%, top5=51.72%]
# Epoch  38/100 | train_loss=3.8364 train_acc=23.56% | val_loss=3.6502 val_acc=27.49% val_top5=51.72% | lr=2.05e-04 peak_mem=1410MB time=47.9s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.15it/s, acc=23.44%, loss=3.8263]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 135.30it/s, loss=3.6107, top1=27.99%, top5=53.11%]
# Epoch  39/100 | train_loss=3.8263 train_acc=23.44% | val_loss=3.6107 val_acc=27.99% val_top5=53.11% | lr=2.01e-04 peak_mem=1410MB time=47.8s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.02it/s, acc=23.77%, loss=3.8180]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 133.88it/s, loss=3.6959, top1=26.36%, top5=50.46%]
# Epoch  40/100 | train_loss=3.8180 train_acc=23.77% | val_loss=3.6959 val_acc=26.36% val_top5=50.46% | lr=1.96e-04 peak_mem=1410MB time=48.0s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.03it/s, acc=23.85%, loss=3.8088]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 126.45it/s, loss=3.6359, top1=27.48%, top5=52.47%]
# Epoch  41/100 | train_loss=3.8088 train_acc=23.85% | val_loss=3.6359 val_acc=27.48% val_top5=52.47% | lr=1.92e-04 peak_mem=1410MB time=48.1s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.05it/s, acc=24.41%, loss=3.7927]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 125.83it/s, loss=3.6277, top1=27.78%, top5=52.77%]
# Epoch  42/100 | train_loss=3.7927 train_acc=24.41% | val_loss=3.6277 val_acc=27.78% val_top5=52.77% | lr=1.87e-04 peak_mem=1410MB time=48.1s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.05it/s, acc=24.24%, loss=3.7857]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 132.44it/s, loss=3.6472, top1=27.47%, top5=52.25%]
# Epoch  43/100 | train_loss=3.7857 train_acc=24.24% | val_loss=3.6472 val_acc=27.47% val_top5=52.25% | lr=1.83e-04 peak_mem=1410MB time=48.0s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.13it/s, acc=24.55%, loss=3.7795]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 133.61it/s, loss=3.6020, top1=28.33%, top5=53.33%]
# Epoch  44/100 | train_loss=3.7795 train_acc=24.55% | val_loss=3.6020 val_acc=28.33% val_top5=53.33% | lr=1.78e-04 peak_mem=1410MB time=47.9s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.12it/s, acc=24.88%, loss=3.7670]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 135.35it/s, loss=3.6098, top1=28.11%, top5=52.84%]
# Epoch  45/100 | train_loss=3.7670 train_acc=24.88% | val_loss=3.6098 val_acc=28.11% val_top5=52.84% | lr=1.73e-04 peak_mem=1410MB time=47.9s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.10it/s, acc=25.14%, loss=3.7556]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 131.96it/s, loss=3.5820, top1=29.34%, top5=53.92%]
# Epoch  46/100 | train_loss=3.7556 train_acc=25.14% | val_loss=3.5820 val_acc=29.34% val_top5=53.92% | lr=1.69e-04 peak_mem=1410MB time=47.9s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.06it/s, acc=25.33%, loss=3.7401]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 122.54it/s, loss=3.5798, top1=28.46%, top5=53.73%]
# Epoch  47/100 | train_loss=3.7401 train_acc=25.33% | val_loss=3.5798 val_acc=28.46% val_top5=53.73% | lr=1.64e-04 peak_mem=1410MB time=48.1s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.06it/s, acc=25.61%, loss=3.7295]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 123.51it/s, loss=3.5767, top1=29.22%, top5=53.73%]
# Epoch  48/100 | train_loss=3.7295 train_acc=25.61% | val_loss=3.5767 val_acc=29.22% val_top5=53.73% | lr=1.59e-04 peak_mem=1410MB time=48.1s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.05it/s, acc=25.54%, loss=3.7220]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 136.63it/s, loss=3.5626, top1=29.24%, top5=54.57%]
# Epoch  49/100 | train_loss=3.7220 train_acc=25.54% | val_loss=3.5626 val_acc=29.24% val_top5=54.57% | lr=1.55e-04 peak_mem=1410MB time=48.0s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.17it/s, acc=26.00%, loss=3.7115]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 136.38it/s, loss=3.5416, top1=29.45%, top5=54.64%]
# Epoch  50/100 | train_loss=3.7115 train_acc=26.00% | val_loss=3.5416 val_acc=29.45% val_top5=54.64% | lr=1.50e-04 peak_mem=1410MB time=47.8s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.12it/s, acc=26.18%, loss=3.7010]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 123.67it/s, loss=3.5449, top1=29.36%, top5=54.72%]
# Epoch  51/100 | train_loss=3.7010 train_acc=26.18% | val_loss=3.5449 val_acc=29.36% val_top5=54.72% | lr=1.45e-04 peak_mem=1410MB time=48.0s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 29.97it/s, acc=26.38%, loss=3.6844]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 126.21it/s, loss=3.5742, top1=29.24%, top5=54.05%]
# Epoch  52/100 | train_loss=3.6844 train_acc=26.38% | val_loss=3.5742 val_acc=29.24% val_top5=54.05% | lr=1.41e-04 peak_mem=1410MB time=48.2s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.03it/s, acc=26.70%, loss=3.6691]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 135.95it/s, loss=3.5410, top1=29.76%, top5=55.05%]
# Epoch  53/100 | train_loss=3.6691 train_acc=26.70% | val_loss=3.5410 val_acc=29.76% val_top5=55.05% | lr=1.36e-04 peak_mem=1410MB time=48.0s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.20it/s, acc=27.05%, loss=3.6608]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 128.79it/s, loss=3.5361, top1=29.61%, top5=54.76%]
# Epoch  54/100 | train_loss=3.6608 train_acc=27.05% | val_loss=3.5361 val_acc=29.61% val_top5=54.76% | lr=1.31e-04 peak_mem=1410MB time=47.8s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.05it/s, acc=27.26%, loss=3.6493]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 114.46it/s, loss=3.5319, top1=29.67%, top5=55.21%]
# Epoch  55/100 | train_loss=3.6493 train_acc=27.26% | val_loss=3.5319 val_acc=29.67% val_top5=55.21% | lr=1.27e-04 peak_mem=1410MB time=48.2s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 29.97it/s, acc=27.33%, loss=3.6445]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 125.00it/s, loss=3.5254, top1=29.77%, top5=55.19%]
# Epoch  56/100 | train_loss=3.6445 train_acc=27.33% | val_loss=3.5254 val_acc=29.77% val_top5=55.19% | lr=1.22e-04 peak_mem=1410MB time=48.2s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 29.97it/s, acc=27.61%, loss=3.6291]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 130.90it/s, loss=3.5205, top1=30.07%, top5=55.31%]
# Epoch  57/100 | train_loss=3.6291 train_acc=27.61% | val_loss=3.5205 val_acc=30.07% val_top5=55.31% | lr=1.17e-04 peak_mem=1410MB time=48.2s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.09it/s, acc=27.95%, loss=3.6127]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 127.45it/s, loss=3.5059, top1=30.38%, top5=55.35%]
# Epoch  58/100 | train_loss=3.6127 train_acc=27.95% | val_loss=3.5059 val_acc=30.38% val_top5=55.35% | lr=1.13e-04 peak_mem=1410MB time=48.0s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.10it/s, acc=28.26%, loss=3.6056]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 117.63it/s, loss=3.4947, top1=30.74%, top5=55.24%]
# Epoch  59/100 | train_loss=3.6056 train_acc=28.26% | val_loss=3.4947 val_acc=30.74% val_top5=55.24% | lr=1.08e-04 peak_mem=1410MB time=48.1s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.06it/s, acc=28.22%, loss=3.6010]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 130.77it/s, loss=3.4915, top1=31.01%, top5=55.92%]
# Epoch  60/100 | train_loss=3.6010 train_acc=28.22% | val_loss=3.4915 val_acc=31.01% val_top5=55.92% | lr=1.04e-04 peak_mem=1410MB time=48.0s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.10it/s, acc=28.74%, loss=3.5832]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 125.79it/s, loss=3.4859, top1=30.52%, top5=55.74%]
# Epoch  61/100 | train_loss=3.5832 train_acc=28.74% | val_loss=3.4859 val_acc=30.52% val_top5=55.74% | lr=9.92e-05 peak_mem=1410MB time=48.0s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.13it/s, acc=28.77%, loss=3.5763]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 138.54it/s, loss=3.4778, top1=31.08%, top5=55.85%]
# Epoch  62/100 | train_loss=3.5763 train_acc=28.77% | val_loss=3.4778 val_acc=31.08% val_top5=55.85% | lr=9.48e-05 peak_mem=1410MB time=47.8s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.15it/s, acc=29.03%, loss=3.5632]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 140.68it/s, loss=3.4798, top1=30.60%, top5=55.97%]
# Epoch  63/100 | train_loss=3.5632 train_acc=29.03% | val_loss=3.4798 val_acc=30.60% val_top5=55.97% | lr=9.04e-05 peak_mem=1410MB time=47.8s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.07it/s, acc=29.35%, loss=3.5516]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 129.72it/s, loss=3.4751, top1=31.02%, top5=56.55%]
# Epoch  64/100 | train_loss=3.5516 train_acc=29.35% | val_loss=3.4751 val_acc=31.02% val_top5=56.55% | lr=8.61e-05 peak_mem=1410MB time=48.0s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 29.98it/s, acc=29.64%, loss=3.5409]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 110.31it/s, loss=3.4581, top1=31.49%, top5=56.88%]
# Epoch  65/100 | train_loss=3.5409 train_acc=29.64% | val_loss=3.4581 val_acc=31.49% val_top5=56.88% | lr=8.19e-05 peak_mem=1410MB time=48.4s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 29.95it/s, acc=29.77%, loss=3.5320]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 120.94it/s, loss=3.4493, top1=31.44%, top5=57.17%]
# Epoch  66/100 | train_loss=3.5320 train_acc=29.77% | val_loss=3.4493 val_acc=31.44% val_top5=57.17% | lr=7.77e-05 peak_mem=1410MB time=48.3s
# Training: 100%|██████████| 1406/1406 [00:47<00:00, 29.91it/s, acc=29.82%, loss=3.5204]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 132.58it/s, loss=3.4633, top1=31.01%, top5=56.62%]
# Epoch  67/100 | train_loss=3.5204 train_acc=29.82% | val_loss=3.4633 val_acc=31.01% val_top5=56.62% | lr=7.36e-05 peak_mem=1410MB time=48.2s
# Training: 100%|██████████| 1406/1406 [00:47<00:00, 29.91it/s, acc=29.98%, loss=3.5165]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 123.15it/s, loss=3.4523, top1=31.47%, top5=56.64%]
# Epoch  68/100 | train_loss=3.5165 train_acc=29.98% | val_loss=3.4523 val_acc=31.47% val_top5=56.64% | lr=6.96e-05 peak_mem=1410MB time=48.3s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 29.98it/s, acc=30.34%, loss=3.5049]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 131.39it/s, loss=3.4135, top1=32.06%, top5=57.72%]
# Epoch  69/100 | train_loss=3.5049 train_acc=30.34% | val_loss=3.4135 val_acc=32.06% val_top5=57.72% | lr=6.57e-05 peak_mem=1410MB time=48.1s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.12it/s, acc=30.40%, loss=3.4996]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 123.21it/s, loss=3.4333, top1=31.93%, top5=57.22%]
# Epoch  70/100 | train_loss=3.4996 train_acc=30.40% | val_loss=3.4333 val_acc=31.93% val_top5=57.22% | lr=6.18e-05 peak_mem=1410MB time=48.0s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 29.99it/s, acc=30.71%, loss=3.4859]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 125.90it/s, loss=3.4160, top1=32.28%, top5=57.66%]
# Epoch  71/100 | train_loss=3.4859 train_acc=30.71% | val_loss=3.4160 val_acc=32.28% val_top5=57.66% | lr=5.81e-05 peak_mem=1410MB time=48.2s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 29.98it/s, acc=30.75%, loss=3.4772]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 119.20it/s, loss=3.4020, top1=32.42%, top5=58.03%]
# Epoch  72/100 | train_loss=3.4772 train_acc=30.75% | val_loss=3.4020 val_acc=32.42% val_top5=58.03% | lr=5.44e-05 peak_mem=1410MB time=48.3s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 29.94it/s, acc=31.11%, loss=3.4666]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 121.76it/s, loss=3.4113, top1=32.28%, top5=57.76%]
# Epoch  73/100 | train_loss=3.4666 train_acc=31.11% | val_loss=3.4113 val_acc=32.28% val_top5=57.76% | lr=5.08e-05 peak_mem=1410MB time=48.3s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.03it/s, acc=31.12%, loss=3.4699]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 108.42it/s, loss=3.3979, top1=32.45%, top5=57.95%]
# Epoch  74/100 | train_loss=3.4699 train_acc=31.12% | val_loss=3.3979 val_acc=32.45% val_top5=57.95% | lr=4.73e-05 peak_mem=1410MB time=48.3s
# Training: 100%|██████████| 1406/1406 [00:47<00:00, 29.83it/s, acc=31.28%, loss=3.4582]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 142.11it/s, loss=3.4037, top1=32.54%, top5=58.17%]
# Epoch  75/100 | train_loss=3.4582 train_acc=31.28% | val_loss=3.4037 val_acc=32.54% val_top5=58.17% | lr=4.39e-05 peak_mem=1410MB time=48.3s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.01it/s, acc=31.48%, loss=3.4428]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 138.20it/s, loss=3.4138, top1=32.35%, top5=57.79%]
# Epoch  76/100 | train_loss=3.4428 train_acc=31.48% | val_loss=3.4138 val_acc=32.35% val_top5=57.79% | lr=4.07e-05 peak_mem=1410MB time=48.0s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.01it/s, acc=31.69%, loss=3.4430]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 138.33it/s, loss=3.4124, top1=32.47%, top5=57.89%]
# Epoch  77/100 | train_loss=3.4430 train_acc=31.69% | val_loss=3.4124 val_acc=32.47% val_top5=57.89% | lr=3.75e-05 peak_mem=1410MB time=48.0s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.03it/s, acc=31.90%, loss=3.4331]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 125.14it/s, loss=3.4154, top1=32.43%, top5=57.64%]
# Epoch  78/100 | train_loss=3.4331 train_acc=31.90% | val_loss=3.4154 val_acc=32.43% val_top5=57.64% | lr=3.44e-05 peak_mem=1410MB time=48.1s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.04it/s, acc=31.99%, loss=3.4276]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 119.99it/s, loss=3.4004, top1=32.80%, top5=58.34%]
# Epoch  79/100 | train_loss=3.4276 train_acc=31.99% | val_loss=3.4004 val_acc=32.80% val_top5=58.34% | lr=3.15e-05 peak_mem=1410MB time=48.2s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.14it/s, acc=32.02%, loss=3.4209]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 133.91it/s, loss=3.3858, top1=32.94%, top5=58.19%]
# Epoch  80/100 | train_loss=3.4209 train_acc=32.02% | val_loss=3.3858 val_acc=32.94% val_top5=58.19% | lr=2.86e-05 peak_mem=1410MB time=47.9s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.09it/s, acc=32.19%, loss=3.4147]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 134.70it/s, loss=3.3895, top1=32.93%, top5=57.83%]
# Epoch  81/100 | train_loss=3.4147 train_acc=32.19% | val_loss=3.3895 val_acc=32.93% val_top5=57.83% | lr=2.59e-05 peak_mem=1410MB time=47.9s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.10it/s, acc=32.21%, loss=3.4103]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 134.93it/s, loss=3.3927, top1=32.40%, top5=58.02%]
# Epoch  82/100 | train_loss=3.4103 train_acc=32.21% | val_loss=3.3927 val_acc=32.40% val_top5=58.02% | lr=2.34e-05 peak_mem=1410MB time=47.9s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 29.93it/s, acc=32.24%, loss=3.4097]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 127.73it/s, loss=3.3983, top1=32.61%, top5=57.95%]
# Epoch  83/100 | train_loss=3.4097 train_acc=32.24% | val_loss=3.3983 val_acc=32.61% val_top5=57.95% | lr=2.09e-05 peak_mem=1410MB time=48.2s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 29.93it/s, acc=32.43%, loss=3.4025]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 115.32it/s, loss=3.3991, top1=32.54%, top5=58.08%]
# Epoch  84/100 | train_loss=3.4025 train_acc=32.43% | val_loss=3.3991 val_acc=32.54% val_top5=58.08% | lr=1.86e-05 peak_mem=1410MB time=48.4s
# Training: 100%|██████████| 1406/1406 [00:46<00:00, 30.02it/s, acc=32.79%, loss=3.3927]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 113.45it/s, loss=3.3829, top1=32.84%, top5=58.31%]
# Epoch  85/100 | train_loss=3.3927 train_acc=32.79% | val_loss=3.3829 val_acc=32.84% val_top5=58.31% | lr=1.63e-05 peak_mem=1410MB time=48.3s
# Early stopping at epoch 85
#
# ================= Run Summary =================
# Model          : alexnet_tv
# Epochs         : 85
# Best Val Top-1 : 32.94%
# Best Val Top-5 : 58.19%
# Final Val Top-1: 32.84%
# Final Val Top-5: 58.31%
# Best Val Loss  : 3.3858
# Total Time     : 01:09:36
# ===============================================
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_val_acc</td><td>▁▂▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇███████</td></tr><tr><td>epoch_time_s</td><td>▄▁▁▂▁▂▂▃▃▄▃▂▅▄▃▄▅▄▄█▄▄▃▄▂▄▃▄▄▄▄▅▅▄▄▄▄▄▃▆</td></tr><tr><td>lr</td><td>██████████▇▇▇▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▅▄▄▃▃▃▂▂▂▁▁</td></tr><tr><td>peak_gpu_mem_mb</td><td>█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_acc</td><td>▁▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇█████</td></tr><tr><td>train_loss</td><td>█▇▇▆▆▆▅▅▅▅▅▅▄▄▄▄▄▄▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▆▅▆▆▆▆▆▆▆▇▇▇▇▇██████████</td></tr><tr><td>val_loss</td><td>█▆▅▅▅▅▅▅▅▄▄▄▄▄▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_top5</td><td>▁▂▂▂▃▃▂▃▃▃▄▄▄▅▄▅▄▅▅▆▆▆▆▆▆▆▆▇▇▇▇█▇███████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_acc</td><td>32.94</td></tr><tr><td>epoch_time_s</td><td>48.26992</td></tr><tr><td>lr</td><td>2e-05</td></tr><tr><td>peak_gpu_mem_mb</td><td>1409.71826</td></tr><tr><td>train_acc</td><td>32.78583</td></tr><tr><td>train_loss</td><td>3.39268</td></tr><tr><td>val_acc</td><td>32.84</td></tr><tr><td>val_loss</td><td>3.3829</td></tr><tr><td>val_top5</td><td>58.31</td></tr></table><br/></div></div>
# You can sync this run to the cloud by running:<br><code>wandb sync /home/rafael/Documents/alexnet_rafael/notebooks/wandb/offline-run-20260630_094445-ibohabrt<code>
# Find logs at: <code>./wandb/offline-run-20260630_094445-ibohabrt/logs</code>
# ========================================================================
# Training: vgg_style  lr=0.001  epochs=100
# ========================================================================
# Tracking run with wandb version 0.28.0
# W&B syncing is set to <code>`offline`<code> in this directory. Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.<br>Run data is saved locally in <code>/home/rafael/Documents/alexnet_rafael/notebooks/wandb/offline-run-20260630_105425-l0365ypg</code><br>View this run in the terminal with <code>`wandb leet`<code>
# Training: 100%|██████████| 1406/1406 [00:25<00:00, 55.76it/s, acc=2.64%, loss=5.0511]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 121.18it/s, loss=4.8260, top1=4.45%, top5=16.71%]
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# Epoch   1/100 | train_loss=5.0511 train_acc=2.64% | val_loss=4.8260 val_acc=4.45% val_top5=16.71% | lr=1.00e-03 peak_mem=504MB time=26.6s
# Training: 100%|██████████| 1406/1406 [00:25<00:00, 55.56it/s, acc=7.62%, loss=4.5851]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 118.78it/s, loss=4.3190, top1=10.78%, top5=31.39%]
# Epoch   2/100 | train_loss=4.5851 train_acc=7.62% | val_loss=4.3190 val_acc=10.78% val_top5=31.39% | lr=9.99e-04 peak_mem=504MB time=26.7s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 53.35it/s, acc=12.10%, loss=4.2965]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 115.47it/s, loss=3.9554, top1=18.78%, top5=43.88%]
# Epoch   3/100 | train_loss=4.2965 train_acc=12.10% | val_loss=3.9554 val_acc=18.78% val_top5=43.88% | lr=9.98e-04 peak_mem=504MB time=27.8s
# Training: 100%|██████████| 1406/1406 [00:25<00:00, 54.46it/s, acc=15.71%, loss=4.1034]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 117.61it/s, loss=3.8543, top1=20.64%, top5=46.54%]
# Epoch   4/100 | train_loss=4.1034 train_acc=15.71% | val_loss=3.8543 val_acc=20.64% val_top5=46.54% | lr=9.96e-04 peak_mem=504MB time=27.2s
# Training: 100%|██████████| 1406/1406 [00:25<00:00, 55.13it/s, acc=19.02%, loss=3.9416]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 116.64it/s, loss=3.6544, top1=25.18%, top5=52.71%]
# Epoch   5/100 | train_loss=3.9416 train_acc=19.02% | val_loss=3.6544 val_acc=25.18% val_top5=52.71% | lr=9.94e-04 peak_mem=504MB time=26.9s
# Training: 100%|██████████| 1406/1406 [00:25<00:00, 54.72it/s, acc=21.84%, loss=3.8106]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 111.17it/s, loss=3.6031, top1=26.61%, top5=54.10%]
# Epoch   6/100 | train_loss=3.8106 train_acc=21.84% | val_loss=3.6031 val_acc=26.61% val_top5=54.10% | lr=9.91e-04 peak_mem=504MB time=27.2s
# Training: 100%|██████████| 1406/1406 [00:25<00:00, 56.01it/s, acc=24.64%, loss=3.6949]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 121.69it/s, loss=3.5929, top1=27.44%, top5=54.31%]
# Epoch   7/100 | train_loss=3.6949 train_acc=24.64% | val_loss=3.5929 val_acc=27.44% val_top5=54.31% | lr=9.88e-04 peak_mem=504MB time=26.4s
# Training: 100%|██████████| 1406/1406 [00:25<00:00, 55.42it/s, acc=26.95%, loss=3.5903]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 116.81it/s, loss=3.3599, top1=32.10%, top5=60.69%]
# Epoch   8/100 | train_loss=3.5903 train_acc=26.95% | val_loss=3.3599 val_acc=32.10% val_top5=60.69% | lr=9.84e-04 peak_mem=504MB time=26.8s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 52.73it/s, acc=28.70%, loss=3.5082]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 124.14it/s, loss=3.2698, top1=35.13%, top5=63.08%]
# Epoch   9/100 | train_loss=3.5082 train_acc=28.70% | val_loss=3.2698 val_acc=35.13% val_top5=63.08% | lr=9.80e-04 peak_mem=504MB time=28.0s
# Training: 100%|██████████| 1406/1406 [00:25<00:00, 55.19it/s, acc=30.82%, loss=3.4288]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 113.36it/s, loss=3.2948, top1=33.96%, top5=62.47%]
# Epoch  10/100 | train_loss=3.4288 train_acc=30.82% | val_loss=3.2948 val_acc=33.96% val_top5=62.47% | lr=9.76e-04 peak_mem=504MB time=26.9s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 53.84it/s, acc=32.36%, loss=3.3603]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 117.24it/s, loss=3.2006, top1=36.66%, top5=64.96%]
# Epoch  11/100 | train_loss=3.3603 train_acc=32.36% | val_loss=3.2006 val_acc=36.66% val_top5=64.96% | lr=9.70e-04 peak_mem=504MB time=27.5s
# Training: 100%|██████████| 1406/1406 [00:28<00:00, 50.12it/s, acc=33.69%, loss=3.3040]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 110.68it/s, loss=3.1308, top1=38.51%, top5=66.60%]
# Epoch  12/100 | train_loss=3.3040 train_acc=33.69% | val_loss=3.1308 val_acc=38.51% val_top5=66.60% | lr=9.65e-04 peak_mem=504MB time=29.5s
# Training: 100%|██████████| 1406/1406 [00:29<00:00, 48.15it/s, acc=35.18%, loss=3.2465]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 110.80it/s, loss=3.1507, top1=37.68%, top5=65.55%]
# Epoch  13/100 | train_loss=3.2465 train_acc=35.18% | val_loss=3.1507 val_acc=37.68% val_top5=65.55% | lr=9.59e-04 peak_mem=504MB time=30.7s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 53.24it/s, acc=36.36%, loss=3.1951]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 120.28it/s, loss=3.1514, top1=38.03%, top5=65.69%]
# Epoch  14/100 | train_loss=3.1951 train_acc=36.36% | val_loss=3.1514 val_acc=38.03% val_top5=65.69% | lr=9.52e-04 peak_mem=504MB time=27.8s
# Training: 100%|██████████| 1406/1406 [00:24<00:00, 56.35it/s, acc=37.27%, loss=3.1532]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 118.56it/s, loss=3.0567, top1=40.80%, top5=67.99%]
# Epoch  15/100 | train_loss=3.1532 train_acc=37.27% | val_loss=3.0567 val_acc=40.80% val_top5=67.99% | lr=9.46e-04 peak_mem=504MB time=26.3s
# Training: 100%|██████████| 1406/1406 [00:25<00:00, 55.89it/s, acc=38.58%, loss=3.1062]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 124.35it/s, loss=2.9672, top1=42.84%, top5=69.95%]
# Epoch  16/100 | train_loss=3.1062 train_acc=38.58% | val_loss=2.9672 val_acc=42.84% val_top5=69.95% | lr=9.38e-04 peak_mem=504MB time=26.5s
# Training: 100%|██████████| 1406/1406 [00:27<00:00, 51.39it/s, acc=39.75%, loss=3.0604]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 115.16it/s, loss=2.9883, top1=42.16%, top5=69.93%]
# Epoch  17/100 | train_loss=3.0604 train_acc=39.75% | val_loss=2.9883 val_acc=42.16% val_top5=69.93% | lr=9.30e-04 peak_mem=504MB time=28.8s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 52.49it/s, acc=40.41%, loss=3.0311]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 118.23it/s, loss=2.9495, top1=43.27%, top5=70.30%]
# Epoch  18/100 | train_loss=3.0311 train_acc=40.41% | val_loss=2.9495 val_acc=43.27% val_top5=70.30% | lr=9.22e-04 peak_mem=504MB time=28.2s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 53.87it/s, acc=41.61%, loss=2.9865]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 118.60it/s, loss=2.9664, top1=43.25%, top5=70.05%]
# Epoch  19/100 | train_loss=2.9865 train_acc=41.61% | val_loss=2.9664 val_acc=43.25% val_top5=70.05% | lr=9.14e-04 peak_mem=504MB time=27.5s
# Training: 100%|██████████| 1406/1406 [00:25<00:00, 55.01it/s, acc=42.60%, loss=2.9510]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 120.98it/s, loss=2.9363, top1=43.73%, top5=70.72%]
# Epoch  20/100 | train_loss=2.9510 train_acc=42.60% | val_loss=2.9363 val_acc=43.73% val_top5=70.72% | lr=9.05e-04 peak_mem=504MB time=26.9s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 53.83it/s, acc=43.29%, loss=2.9202]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 109.31it/s, loss=2.9429, top1=43.66%, top5=70.63%]
# Epoch  21/100 | train_loss=2.9202 train_acc=43.29% | val_loss=2.9429 val_acc=43.66% val_top5=70.63% | lr=8.95e-04 peak_mem=504MB time=27.6s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 53.03it/s, acc=43.97%, loss=2.8913]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 115.41it/s, loss=2.8772, top1=45.62%, top5=71.97%]
# Epoch  22/100 | train_loss=2.8913 train_acc=43.97% | val_loss=2.8772 val_acc=45.62% val_top5=71.97% | lr=8.85e-04 peak_mem=504MB time=27.9s
# Training: 100%|██████████| 1406/1406 [00:25<00:00, 54.83it/s, acc=44.75%, loss=2.8602]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 118.07it/s, loss=2.9250, top1=44.39%, top5=70.63%]
# Epoch  23/100 | train_loss=2.8602 train_acc=44.75% | val_loss=2.9250 val_acc=44.39% val_top5=70.63% | lr=8.75e-04 peak_mem=504MB time=27.0s
# Training: 100%|██████████| 1406/1406 [00:25<00:00, 55.49it/s, acc=45.17%, loss=2.8382]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 111.25it/s, loss=2.8699, top1=45.88%, top5=72.06%]
# Epoch  24/100 | train_loss=2.8382 train_acc=45.17% | val_loss=2.8699 val_acc=45.88% val_top5=72.06% | lr=8.64e-04 peak_mem=504MB time=26.8s
# Training: 100%|██████████| 1406/1406 [00:28<00:00, 48.93it/s, acc=46.35%, loss=2.8055]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 109.46it/s, loss=2.8447, top1=46.33%, top5=72.79%]
# Epoch  25/100 | train_loss=2.8055 train_acc=46.35% | val_loss=2.8447 val_acc=46.33% val_top5=72.79% | lr=8.54e-04 peak_mem=504MB time=30.2s
# Training: 100%|██████████| 1406/1406 [00:28<00:00, 48.64it/s, acc=46.60%, loss=2.7835]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 105.44it/s, loss=2.9059, top1=44.50%, top5=71.28%]
# Epoch  26/100 | train_loss=2.7835 train_acc=46.60% | val_loss=2.9059 val_acc=44.50% val_top5=71.28% | lr=8.42e-04 peak_mem=504MB time=30.5s
# Training: 100%|██████████| 1406/1406 [00:29<00:00, 47.57it/s, acc=47.32%, loss=2.7624]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 112.51it/s, loss=2.8641, top1=46.30%, top5=72.53%]
# Epoch  27/100 | train_loss=2.7624 train_acc=47.32% | val_loss=2.8641 val_acc=46.30% val_top5=72.53% | lr=8.31e-04 peak_mem=504MB time=31.0s
# Training: 100%|██████████| 1406/1406 [00:29<00:00, 46.93it/s, acc=48.10%, loss=2.7397]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 96.58it/s, loss=2.8046, top1=47.54%, top5=73.78%]
# Epoch  28/100 | train_loss=2.7397 train_acc=48.10% | val_loss=2.8046 val_acc=47.54% val_top5=73.78% | lr=8.19e-04 peak_mem=504MB time=31.7s
# Training: 100%|██████████| 1406/1406 [00:29<00:00, 48.26it/s, acc=48.49%, loss=2.7148]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 116.12it/s, loss=2.8060, top1=47.59%, top5=74.04%]
# Epoch  29/100 | train_loss=2.7148 train_acc=48.49% | val_loss=2.8060 val_acc=47.59% val_top5=74.04% | lr=8.06e-04 peak_mem=504MB time=30.5s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 53.70it/s, acc=48.99%, loss=2.6997]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 117.81it/s, loss=2.8162, top1=48.06%, top5=73.84%]
# Epoch  30/100 | train_loss=2.6997 train_acc=48.99% | val_loss=2.8162 val_acc=48.06% val_top5=73.84% | lr=7.94e-04 peak_mem=504MB time=27.6s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 52.52it/s, acc=49.71%, loss=2.6715]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 111.53it/s, loss=2.7969, top1=48.65%, top5=73.80%]
# Epoch  31/100 | train_loss=2.6715 train_acc=49.71% | val_loss=2.7969 val_acc=48.65% val_top5=73.80% | lr=7.81e-04 peak_mem=504MB time=28.2s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 53.79it/s, acc=50.22%, loss=2.6506]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 116.40it/s, loss=2.8085, top1=47.65%, top5=73.92%]
# Epoch  32/100 | train_loss=2.6506 train_acc=50.22% | val_loss=2.8085 val_acc=47.65% val_top5=73.92% | lr=7.68e-04 peak_mem=504MB time=27.5s
# Training: 100%|██████████| 1406/1406 [00:27<00:00, 51.78it/s, acc=51.07%, loss=2.6310]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 119.73it/s, loss=2.8425, top1=47.15%, top5=72.99%]
# Epoch  33/100 | train_loss=2.6310 train_acc=51.07% | val_loss=2.8425 val_acc=47.15% val_top5=72.99% | lr=7.55e-04 peak_mem=504MB time=28.5s
# Training: 100%|██████████| 1406/1406 [00:27<00:00, 50.54it/s, acc=51.11%, loss=2.6165]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 113.91it/s, loss=2.8425, top1=47.27%, top5=73.06%]
# Epoch  34/100 | train_loss=2.6165 train_acc=51.11% | val_loss=2.8425 val_acc=47.27% val_top5=73.06% | lr=7.41e-04 peak_mem=504MB time=29.3s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 52.56it/s, acc=51.86%, loss=2.5916]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 116.42it/s, loss=2.7867, top1=48.25%, top5=74.61%]
# Epoch  35/100 | train_loss=2.5916 train_acc=51.86% | val_loss=2.7867 val_acc=48.25% val_top5=74.61% | lr=7.27e-04 peak_mem=504MB time=28.2s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 53.26it/s, acc=52.08%, loss=2.5810]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 112.56it/s, loss=2.7699, top1=49.10%, top5=74.73%]
# Epoch  36/100 | train_loss=2.5810 train_acc=52.08% | val_loss=2.7699 val_acc=49.10% val_top5=74.73% | lr=7.13e-04 peak_mem=504MB time=27.9s
# Training: 100%|██████████| 1406/1406 [00:28<00:00, 49.93it/s, acc=52.77%, loss=2.5566]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 117.28it/s, loss=2.7719, top1=49.41%, top5=74.66%]
# Epoch  37/100 | train_loss=2.5566 train_acc=52.77% | val_loss=2.7719 val_acc=49.41% val_top5=74.66% | lr=6.99e-04 peak_mem=504MB time=29.5s
# Training: 100%|██████████| 1406/1406 [00:27<00:00, 51.26it/s, acc=53.11%, loss=2.5434]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 118.59it/s, loss=2.7702, top1=48.99%, top5=74.56%]
# Epoch  38/100 | train_loss=2.5434 train_acc=53.11% | val_loss=2.7702 val_acc=48.99% val_top5=74.56% | lr=6.84e-04 peak_mem=504MB time=28.8s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 52.30it/s, acc=53.79%, loss=2.5256]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 114.82it/s, loss=2.7875, top1=49.21%, top5=74.19%]
# Epoch  39/100 | train_loss=2.5256 train_acc=53.79% | val_loss=2.7875 val_acc=49.21% val_top5=74.19% | lr=6.69e-04 peak_mem=504MB time=28.3s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 52.38it/s, acc=54.33%, loss=2.5119]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 110.84it/s, loss=2.7659, top1=49.67%, top5=74.98%]
# Epoch  40/100 | train_loss=2.5119 train_acc=54.33% | val_loss=2.7659 val_acc=49.67% val_top5=74.98% | lr=6.55e-04 peak_mem=504MB time=28.3s
# Training: 100%|██████████| 1406/1406 [00:27<00:00, 50.94it/s, acc=54.49%, loss=2.4938]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 115.20it/s, loss=2.7720, top1=49.45%, top5=74.49%]
# Epoch  41/100 | train_loss=2.4938 train_acc=54.49% | val_loss=2.7720 val_acc=49.45% val_top5=74.49% | lr=6.39e-04 peak_mem=504MB time=29.0s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 52.50it/s, acc=55.30%, loss=2.4720]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 114.68it/s, loss=2.7884, top1=48.62%, top5=74.03%]
# Epoch  42/100 | train_loss=2.4720 train_acc=55.30% | val_loss=2.7884 val_acc=48.62% val_top5=74.03% | lr=6.24e-04 peak_mem=504MB time=28.2s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 52.43it/s, acc=55.64%, loss=2.4604]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 113.11it/s, loss=2.7762, top1=49.31%, top5=74.58%]
# Epoch  43/100 | train_loss=2.4604 train_acc=55.64% | val_loss=2.7762 val_acc=49.31% val_top5=74.58% | lr=6.09e-04 peak_mem=504MB time=28.3s
# Training: 100%|██████████| 1406/1406 [00:27<00:00, 51.70it/s, acc=55.81%, loss=2.4493]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 111.38it/s, loss=2.7544, top1=50.35%, top5=75.20%]
# Epoch  44/100 | train_loss=2.4493 train_acc=55.81% | val_loss=2.7544 val_acc=50.35% val_top5=75.20% | lr=5.94e-04 peak_mem=504MB time=28.7s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 52.70it/s, acc=56.15%, loss=2.4339]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 115.03it/s, loss=2.7525, top1=50.19%, top5=75.10%]
# Epoch  45/100 | train_loss=2.4339 train_acc=56.15% | val_loss=2.7525 val_acc=50.19% val_top5=75.10% | lr=5.78e-04 peak_mem=504MB time=28.1s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 52.42it/s, acc=56.84%, loss=2.4138]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 106.85it/s, loss=2.7699, top1=49.48%, top5=74.98%]
# Epoch  46/100 | train_loss=2.4138 train_acc=56.84% | val_loss=2.7699 val_acc=49.48% val_top5=74.98% | lr=5.63e-04 peak_mem=504MB time=28.4s
# Training: 100%|██████████| 1406/1406 [00:27<00:00, 50.87it/s, acc=57.13%, loss=2.4013]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 113.28it/s, loss=2.7463, top1=50.47%, top5=75.26%]
# Epoch  47/100 | train_loss=2.4013 train_acc=57.13% | val_loss=2.7463 val_acc=50.47% val_top5=75.26% | lr=5.47e-04 peak_mem=504MB time=29.1s
# Training: 100%|██████████| 1406/1406 [00:28<00:00, 48.90it/s, acc=57.56%, loss=2.3903]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 113.11it/s, loss=2.7479, top1=50.49%, top5=75.48%]
# Epoch  48/100 | train_loss=2.3903 train_acc=57.56% | val_loss=2.7479 val_acc=50.49% val_top5=75.48% | lr=5.31e-04 peak_mem=504MB time=30.2s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 52.85it/s, acc=57.85%, loss=2.3785]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 118.05it/s, loss=2.7605, top1=50.29%, top5=75.06%]
# Epoch  49/100 | train_loss=2.3785 train_acc=57.85% | val_loss=2.7605 val_acc=50.29% val_top5=75.06% | lr=5.16e-04 peak_mem=504MB time=28.0s
# ...
# Epoch  21/100 | train_loss=2.1475 train_acc=63.31% | val_loss=2.6417 val_acc=52.26% val_top5=76.84% | lr=8.95e-05 peak_mem=542MB time=28.7s
# Early stopping at epoch 21
#
# ================= Run Summary =================
# Model          : resnet18_tv
# Epochs         : 21
# Best Val Top-1 : 53.98%
# Best Val Top-5 : 77.80%
# Final Val Top-1: 52.26%
# Final Val Top-5: 76.84%
# Best Val Loss  : 2.5613
# Total Time     : 00:09:58
# ===============================================
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_val_acc</td><td>▁▄▄▅▆▇▇▇▇███</td></tr><tr><td>epoch_time_s</td><td>▄▅▆▃▃▂▃▅▃▂▄▃▄█▆▂▃▂▁▂▄</td></tr><tr><td>lr</td><td>█████▇▇▇▇▆▆▆▅▅▄▄▃▃▂▂▁</td></tr><tr><td>peak_gpu_mem_mb</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_acc</td><td>▁▃▄▄▅▅▅▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>train_loss</td><td>█▅▅▄▄▄▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▄▄▅▆▇▆▇▇▇▇▇██▇███▇▇▇</td></tr><tr><td>val_loss</td><td>█▅▄▃▂▂▂▁▂▁▁▁▁▁▁▁▁▁▂▂▂</td></tr><tr><td>val_top5</td><td>▁▄▅▆▇▇▇▇▇████▇▇█▇█▇▇▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_acc</td><td>53.98</td></tr><tr><td>epoch_time_s</td><td>28.74837</td></tr><tr><td>lr</td><td>9e-05</td></tr><tr><td>peak_gpu_mem_mb</td><td>541.729</td></tr><tr><td>train_acc</td><td>63.30903</td></tr><tr><td>train_loss</td><td>2.14749</td></tr><tr><td>val_acc</td><td>52.26</td></tr><tr><td>val_loss</td><td>2.6417</td></tr><tr><td>val_top5</td><td>76.84</td></tr></table><br/></div></div>
# You can sync this run to the cloud by running:<br><code>wandb sync /home/rafael/Documents/alexnet_rafael/notebooks/wandb/offline-run-20260630_112755-zdpvyjip<code>
# Find logs at: <code>./wandb/offline-run-20260630_112755-zdpvyjip/logs</code>
# ========================================================================
# Training: mobilenetv2  lr=0.0001  epochs=100
# ========================================================================
# Tracking run with wandb version 0.28.0
# W&B syncing is set to <code>`offline`<code> in this directory. Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.<br>Run data is saved locally in <code>/home/rafael/Documents/alexnet_rafael/notebooks/wandb/offline-run-20260630_113754-0hs5kdgi</code><br>View this run in the terminal with <code>`wandb leet`<code>
# Training: 100%|██████████| 1406/1406 [00:31<00:00, 44.90it/s, acc=21.74%, loss=3.9609]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 86.45it/s, loss=2.9765, top1=42.02%, top5=69.92%]
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# Epoch   1/100 | train_loss=3.9609 train_acc=21.74% | val_loss=2.9765 val_acc=42.02% val_top5=69.92% | lr=1.00e-04 peak_mem=537MB time=33.2s
# Training: 100%|██████████| 1406/1406 [00:35<00:00, 39.15it/s, acc=36.40%, loss=3.1968]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 104.44it/s, loss=2.7111, top1=47.81%, top5=74.96%]
# Epoch   2/100 | train_loss=3.1968 train_acc=36.40% | val_loss=2.7111 val_acc=47.81% val_top5=74.96% | lr=9.99e-05 peak_mem=537MB time=37.5s
# Training: 100%|██████████| 1406/1406 [00:33<00:00, 41.69it/s, acc=40.78%, loss=2.9975]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 100.98it/s, loss=2.5980, top1=51.06%, top5=76.91%]
# Epoch   3/100 | train_loss=2.9975 train_acc=40.78% | val_loss=2.5980 val_acc=51.06% val_top5=76.91% | lr=9.98e-05 peak_mem=537MB time=35.3s
# Training: 100%|██████████| 1406/1406 [00:33<00:00, 41.50it/s, acc=43.57%, loss=2.8846]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 104.08it/s, loss=2.5487, top1=52.29%, top5=77.90%]
# Epoch   4/100 | train_loss=2.8846 train_acc=43.57% | val_loss=2.5487 val_acc=52.29% val_top5=77.90% | lr=9.96e-05 peak_mem=537MB time=35.4s
# Training: 100%|██████████| 1406/1406 [00:33<00:00, 41.97it/s, acc=45.35%, loss=2.8101]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 102.11it/s, loss=2.4843, top1=54.12%, top5=78.78%]
# Epoch   5/100 | train_loss=2.8101 train_acc=45.35% | val_loss=2.4843 val_acc=54.12% val_top5=78.78% | lr=9.94e-05 peak_mem=537MB time=35.1s
# Training: 100%|██████████| 1406/1406 [00:32<00:00, 43.51it/s, acc=46.93%, loss=2.7441]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 108.04it/s, loss=2.4602, top1=54.74%, top5=79.33%]
# Epoch   6/100 | train_loss=2.7441 train_acc=46.93% | val_loss=2.4602 val_acc=54.74% val_top5=79.33% | lr=9.91e-05 peak_mem=537MB time=33.8s
# Training: 100%|██████████| 1406/1406 [00:34<00:00, 40.68it/s, acc=48.25%, loss=2.6899]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 95.50it/s, loss=2.4405, top1=54.90%, top5=79.86%]
# Epoch   7/100 | train_loss=2.6899 train_acc=48.25% | val_loss=2.4405 val_acc=54.90% val_top5=79.86% | lr=9.88e-05 peak_mem=537MB time=36.3s
# Training: 100%|██████████| 1406/1406 [00:33<00:00, 42.60it/s, acc=49.44%, loss=2.6406]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 104.17it/s, loss=2.4339, top1=55.74%, top5=80.21%]
# Epoch   8/100 | train_loss=2.6406 train_acc=49.44% | val_loss=2.4339 val_acc=55.74% val_top5=80.21% | lr=9.84e-05 peak_mem=537MB time=34.6s
# Training: 100%|██████████| 1406/1406 [00:32<00:00, 42.96it/s, acc=50.46%, loss=2.6058]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 107.49it/s, loss=2.4195, top1=56.18%, top5=80.32%]
# Epoch   9/100 | train_loss=2.6058 train_acc=50.46% | val_loss=2.4195 val_acc=56.18% val_top5=80.32% | lr=9.80e-05 peak_mem=537MB time=34.3s
# Training: 100%|██████████| 1406/1406 [00:28<00:00, 48.57it/s, acc=51.47%, loss=2.5655]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 113.87it/s, loss=2.4418, top1=54.87%, top5=79.85%]
# Epoch  10/100 | train_loss=2.5655 train_acc=51.47% | val_loss=2.4418 val_acc=54.87% val_top5=79.85% | lr=9.76e-05 peak_mem=537MB time=30.4s
# Training: 100%|██████████| 1406/1406 [00:27<00:00, 51.31it/s, acc=52.31%, loss=2.5375]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 126.57it/s, loss=2.3910, top1=56.68%, top5=80.89%]
# Epoch  11/100 | train_loss=2.5375 train_acc=52.31% | val_loss=2.3910 val_acc=56.68% val_top5=80.89% | lr=9.70e-05 peak_mem=537MB time=28.7s
# Training: 100%|██████████| 1406/1406 [00:28<00:00, 48.94it/s, acc=52.80%, loss=2.5101]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 119.05it/s, loss=2.4176, top1=55.97%, top5=80.11%]
# Epoch  12/100 | train_loss=2.5101 train_acc=52.80% | val_loss=2.4176 val_acc=55.97% val_top5=80.11% | lr=9.65e-05 peak_mem=537MB time=30.1s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 52.61it/s, acc=53.78%, loss=2.4768]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 125.72it/s, loss=2.4012, top1=56.30%, top5=80.91%]
# Epoch  13/100 | train_loss=2.4768 train_acc=53.78% | val_loss=2.4012 val_acc=56.30% val_top5=80.91% | lr=9.59e-05 peak_mem=537MB time=28.0s
# Training: 100%|██████████| 1406/1406 [00:25<00:00, 54.32it/s, acc=54.39%, loss=2.4524]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 129.07it/s, loss=2.3808, top1=57.12%, top5=81.00%]
# Epoch  14/100 | train_loss=2.4524 train_acc=54.39% | val_loss=2.3808 val_acc=57.12% val_top5=81.00% | lr=9.52e-05 peak_mem=537MB time=27.2s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 52.31it/s, acc=55.00%, loss=2.4298]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 124.21it/s, loss=2.4014, top1=56.40%, top5=80.70%]
# Epoch  15/100 | train_loss=2.4298 train_acc=55.00% | val_loss=2.4014 val_acc=56.40% val_top5=80.70% | lr=9.46e-05 peak_mem=537MB time=28.2s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 53.48it/s, acc=55.48%, loss=2.4084]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 112.34it/s, loss=2.3747, top1=57.43%, top5=81.41%]
# Epoch  16/100 | train_loss=2.4084 train_acc=55.48% | val_loss=2.3747 val_acc=57.43% val_top5=81.41% | lr=9.38e-05 peak_mem=537MB time=27.7s
# Training: 100%|██████████| 1406/1406 [00:29<00:00, 47.90it/s, acc=56.39%, loss=2.3822]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 108.40it/s, loss=2.3817, top1=57.14%, top5=81.35%]
# Epoch  17/100 | train_loss=2.3822 train_acc=56.39% | val_loss=2.3817 val_acc=57.14% val_top5=81.35% | lr=9.30e-05 peak_mem=537MB time=30.9s
# Training: 100%|██████████| 1406/1406 [00:27<00:00, 51.81it/s, acc=56.76%, loss=2.3625]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 119.74it/s, loss=2.3979, top1=56.53%, top5=80.91%]
# Epoch  18/100 | train_loss=2.3625 train_acc=56.76% | val_loss=2.3979 val_acc=56.53% val_top5=80.91% | lr=9.22e-05 peak_mem=537MB time=28.5s
# Training: 100%|██████████| 1406/1406 [00:26<00:00, 52.65it/s, acc=57.21%, loss=2.3474]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 124.67it/s, loss=2.3785, top1=57.40%, top5=81.26%]
# Epoch  19/100 | train_loss=2.3474 train_acc=57.21% | val_loss=2.3785 val_acc=57.40% val_top5=81.26% | lr=9.14e-05 peak_mem=537MB time=28.0s
# Training: 100%|██████████| 1406/1406 [00:25<00:00, 54.95it/s, acc=57.59%, loss=2.3261]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 133.28it/s, loss=2.3852, top1=57.40%, top5=81.23%]
# Epoch  20/100 | train_loss=2.3261 train_acc=57.59% | val_loss=2.3852 val_acc=57.40% val_top5=81.23% | lr=9.05e-05 peak_mem=537MB time=26.8s
# Training: 100%|██████████| 1406/1406 [00:24<00:00, 57.28it/s, acc=58.37%, loss=2.3042]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 126.46it/s, loss=2.3764, top1=57.48%, top5=81.40%]
# Epoch  21/100 | train_loss=2.3042 train_acc=58.37% | val_loss=2.3764 val_acc=57.48% val_top5=81.40% | lr=8.95e-05 peak_mem=537MB time=25.8s
# Training: 100%|██████████| 1406/1406 [00:25<00:00, 55.96it/s, acc=58.70%, loss=2.2909]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 127.57it/s, loss=2.3893, top1=56.88%, top5=81.14%]
# Epoch  22/100 | train_loss=2.2909 train_acc=58.70% | val_loss=2.3893 val_acc=56.88% val_top5=81.14% | lr=8.85e-05 peak_mem=537MB time=26.4s
# Training: 100%|██████████| 1406/1406 [00:30<00:00, 46.18it/s, acc=59.14%, loss=2.2770]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 97.66it/s, loss=2.4039, top1=57.19%, top5=80.75%]
# Epoch  23/100 | train_loss=2.2770 train_acc=59.14% | val_loss=2.4039 val_acc=57.19% val_top5=80.75% | lr=8.75e-05 peak_mem=537MB time=32.1s
# Training: 100%|██████████| 1406/1406 [00:33<00:00, 41.40it/s, acc=59.58%, loss=2.2589]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 97.77it/s, loss=2.4040, top1=57.05%, top5=80.99%]
# Epoch  24/100 | train_loss=2.2589 train_acc=59.58% | val_loss=2.4040 val_acc=57.05% val_top5=80.99% | lr=8.64e-05 peak_mem=537MB time=35.6s
# Training: 100%|██████████| 1406/1406 [00:34<00:00, 41.23it/s, acc=60.00%, loss=2.2408]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 91.71it/s, loss=2.3851, top1=57.55%, top5=81.43%]
# Epoch  25/100 | train_loss=2.2408 train_acc=60.00% | val_loss=2.3851 val_acc=57.55% val_top5=81.43% | lr=8.54e-05 peak_mem=537MB time=35.9s
# Training: 100%|██████████| 1406/1406 [00:37<00:00, 37.98it/s, acc=60.49%, loss=2.2296]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 88.81it/s, loss=2.3807, top1=57.83%, top5=81.10%]
# Epoch  26/100 | train_loss=2.2296 train_acc=60.49% | val_loss=2.3807 val_acc=57.83% val_top5=81.10% | lr=8.42e-05 peak_mem=537MB time=38.9s
# Training: 100%|██████████| 1406/1406 [00:39<00:00, 36.05it/s, acc=60.74%, loss=2.2166]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 96.62it/s, loss=2.3788, top1=57.75%, top5=81.56%]
# Epoch  27/100 | train_loss=2.2166 train_acc=60.74% | val_loss=2.3788 val_acc=57.75% val_top5=81.56% | lr=8.31e-05 peak_mem=537MB time=40.7s
# Training: 100%|██████████| 1406/1406 [00:34<00:00, 40.18it/s, acc=61.27%, loss=2.2024]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 102.84it/s, loss=2.3662, top1=58.07%, top5=81.50%]
# Epoch  28/100 | train_loss=2.2024 train_acc=61.27% | val_loss=2.3662 val_acc=58.07% val_top5=81.50% | lr=8.19e-05 peak_mem=537MB time=36.6s
# Training: 100%|██████████| 1406/1406 [00:33<00:00, 41.69it/s, acc=61.69%, loss=2.1854]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 88.53it/s, loss=2.3805, top1=57.45%, top5=81.21%]
# Epoch  29/100 | train_loss=2.1854 train_acc=61.69% | val_loss=2.3805 val_acc=57.45% val_top5=81.21% | lr=8.06e-05 peak_mem=537MB time=35.6s
# Training: 100%|██████████| 1406/1406 [00:36<00:00, 38.13it/s, acc=62.29%, loss=2.1681]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 96.82it/s, loss=2.3864, top1=57.74%, top5=80.99%]
# Epoch  30/100 | train_loss=2.1681 train_acc=62.29% | val_loss=2.3864 val_acc=57.74% val_top5=80.99% | lr=7.94e-05 peak_mem=537MB time=38.6s
# Training: 100%|██████████| 1406/1406 [00:35<00:00, 39.34it/s, acc=62.51%, loss=2.1619]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 91.21it/s, loss=2.3868, top1=57.93%, top5=81.11%]
# Epoch  31/100 | train_loss=2.1619 train_acc=62.51% | val_loss=2.3868 val_acc=57.93% val_top5=81.11% | lr=7.81e-05 peak_mem=537MB time=37.5s
# Training: 100%|██████████| 1406/1406 [00:33<00:00, 41.72it/s, acc=62.69%, loss=2.1487]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 96.11it/s, loss=2.3870, top1=57.77%, top5=81.01%]
# Epoch  32/100 | train_loss=2.1487 train_acc=62.69% | val_loss=2.3870 val_acc=57.77% val_top5=81.01% | lr=7.68e-05 peak_mem=537MB time=35.4s
# Training: 100%|██████████| 1406/1406 [00:34<00:00, 41.25it/s, acc=63.09%, loss=2.1336]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 97.65it/s, loss=2.3850, top1=57.80%, top5=81.28%]
# Epoch  33/100 | train_loss=2.1336 train_acc=63.09% | val_loss=2.3850 val_acc=57.80% val_top5=81.28% | lr=7.55e-05 peak_mem=537MB time=35.8s
# Early stopping at epoch 33
#
# ================= Run Summary =================
# Model          : mobilenetv2
# Epochs         : 33
# Best Val Top-1 : 58.07%
# Best Val Top-5 : 81.50%
# Final Val Top-1: 57.80%
# Final Val Top-5: 81.28%
# Best Val Loss  : 2.3662
# Total Time     : 00:18:07
# ===============================================
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_val_acc</td><td>▁▄▅▅▆▇▇▇▇▇██████</td></tr><tr><td>epoch_time_s</td><td>▄▆▅▆▅▅▆▅▅▃▂▃▂▂▂▂▃▂▂▁▁▁▄▆▆▇█▆▆▇▇▆▆</td></tr><tr><td>lr</td><td>████████▇▇▇▇▇▇▆▆▆▆▆▅▅▅▄▄▄▄▃▃▂▂▂▁▁</td></tr><tr><td>peak_gpu_mem_mb</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_acc</td><td>▁▃▄▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇████████</td></tr><tr><td>train_loss</td><td>█▅▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_acc</td><td>▁▄▅▅▆▇▇▇▇▇▇▇▇█▇██▇███▇███████████</td></tr><tr><td>val_loss</td><td>█▅▄▃▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_top5</td><td>▁▄▅▆▆▇▇▇▇▇█▇██▇██████████████████</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_acc</td><td>58.07</td></tr><tr><td>epoch_time_s</td><td>35.75439</td></tr><tr><td>lr</td><td>8e-05</td></tr><tr><td>peak_gpu_mem_mb</td><td>536.68164</td></tr><tr><td>train_acc</td><td>63.08566</td></tr><tr><td>train_loss</td><td>2.13362</td></tr><tr><td>val_acc</td><td>57.8</td></tr><tr><td>val_loss</td><td>2.38498</td></tr><tr><td>val_top5</td><td>81.28</td></tr></table><br/></div></div>
# You can sync this run to the cloud by running:<br><code>wandb sync /home/rafael/Documents/alexnet_rafael/notebooks/wandb/offline-run-20260630_113754-0hs5kdgi<code>
# Find logs at: <code>./wandb/offline-run-20260630_113754-0hs5kdgi/logs</code>
# FP32 training complete.

# %% [markdown]
# ## 6. Quantization-Aware Training (QAT)
#
# `ResNet18TV` and `MobileNetV2TV` are excluded: their residual adds (`+` / inverted bottleneck)
# aren't interceptable by fake-quant observers without `FloatFunctional`.
# QAT trains on GPU; `convert` and INT8 inference run on CPU (fbgemm).

# %%
QAT_SKIP = {"resnet18_tv", "mobilenetv2"}  # ponytail: no FloatFunctional residual adds

qat_train_cfg = replace(
    fp32_cfg,
    epochs=qat_cfg.epochs,
    lr=qat_cfg.lr,
    weight_decay=qat_cfg.weight_decay,
    use_amp=False,  # AMP incompatible with fake-quant observers
)

qat_models = {}
qat_training_results = {}

for name in MODEL_REGISTRY:
    if name in QAT_SKIP:
        print(f"Skipping QAT for {name} (QAT_SKIP).")
        continue

    # Auto-detect resume checkpoint
    resume_from = auto_resume_path(SAVE_DIR, f"qat_{name}")
    
    # If best already exists and no resume checkpoint, skip
    if (SAVE_DIR / f"qat_{name}_best.pth").exists() and not resume_from:
        print(f"Skipping QAT for {name} (checkpoint found).")
        continue
    
    # Restore W&B run if resuming
    run_id = None
    if resume_from:
        meta_path = SAVE_DIR / f"qat_{name}_meta.json"
        if meta_path.exists():
            run_id = json.loads(meta_path.read_text()).get("wandb_run_id")

    print("=" * 72)
    print(f"QAT fine-tuning: {name}")
    if resume_from:
        print(f"(Resuming from checkpoint)")
    print("=" * 72)

    qat_model = build_qat(name, save_dir=SAVE_DIR, device=device)
    cb = make_qat_callback(qat_cfg.freeze_bn_epoch, qat_cfg.disable_observer_epoch)

    run = wandb.init(
        project="alexnet-baselines",
        group="qat-baselines",
        name=f"{name}_qat",
        id=run_id,
        resume="allow" if run_id else None,
        config={
            **asdict(qat_train_cfg),
            "arch": name,
            "phase": "qat",
            "freeze_bn_epoch": qat_cfg.freeze_bn_epoch,
            "disable_observer_epoch": qat_cfg.disable_observer_epoch,
            "num_classes": data_cfg.num_classes, "img_size": data_cfg.img_size,
            "dataset": "tiny-imagenet-200",
        },
        tags=["phase1", "baselines", "tiny-imagenet", "qat"],
        mode="offline",
    )

    trainer = Trainer(
        qat_model, train_loader, val_loader, qat_train_cfg,
        device, SAVE_DIR, f"qat_{name}", num_classes=data_cfg.num_classes,
        wandb_run=run,
        epoch_callback=cb,
        log_file=SAVE_DIR / f"qat_{name}.log",
    )
    results = trainer.fit(resume_from=resume_from)
    wandb.finish()

    qat_training_results[name] = results
    qat_models[name] = qat_model.cpu()

    del qat_model
    torch.cuda.empty_cache()

print("\nQAT training complete.")
# Out:
# ========================================================================
# QAT fine-tuning: alexnet_tv
# ========================================================================
# /home/rafael/Documents/alexnet_rafael/.venv/lib/python3.12/site-packages/torch/ao/quantization/observer.py:229: UserWarning: Please use quant_min and quant_max to specify the range for observers.                     reduce_range will be deprecated in a future release of PyTorch.
#   warnings.warn(
# Tracking run with wandb version 0.28.0
# W&B syncing is set to <code>`offline`<code> in this directory. Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.<br>Run data is saved locally in <code>/home/rafael/Documents/alexnet_rafael/notebooks/wandb/offline-run-20260630_115603-kcn6r9ke</code><br>View this run in the terminal with <code>`wandb leet`<code>
# Training: 100%|██████████| 1406/1406 [00:50<00:00, 27.77it/s, acc=30.30%, loss=3.5210]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 101.67it/s, loss=3.4410, top1=31.74%, top5=56.84%]
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# Epoch   1/20 | train_loss=3.5210 train_acc=30.30% | val_loss=3.4410 val_acc=31.74% val_top5=56.84% | lr=9.94e-06 peak_mem=1414MB time=52.2s
# Training: 100%|██████████| 1406/1406 [00:49<00:00, 28.26it/s, acc=30.48%, loss=3.5071]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 100.30it/s, loss=3.4295, top1=31.63%, top5=57.13%]
# Epoch   2/20 | train_loss=3.5071 train_acc=30.48% | val_loss=3.4295 val_acc=31.63% val_top5=57.13% | lr=9.76e-06 peak_mem=1414MB time=51.4s
# Training: 100%|██████████| 1406/1406 [00:49<00:00, 28.23it/s, acc=30.39%, loss=3.5069]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 101.54it/s, loss=3.4379, top1=32.20%, top5=57.11%]
# Epoch   3/20 | train_loss=3.5069 train_acc=30.39% | val_loss=3.4379 val_acc=32.20% val_top5=57.11% | lr=9.46e-06 peak_mem=1414MB time=51.4s
# Training: 100%|██████████| 1406/1406 [00:49<00:00, 28.33it/s, acc=30.49%, loss=3.5005]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 102.86it/s, loss=3.4371, top1=32.01%, top5=57.43%]
# Epoch   4/20 | train_loss=3.5005 train_acc=30.49% | val_loss=3.4371 val_acc=32.01% val_top5=57.43% | lr=9.05e-06 peak_mem=1414MB time=51.2s
# Training: 100%|██████████| 1406/1406 [00:49<00:00, 28.30it/s, acc=30.62%, loss=3.4978]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 102.79it/s, loss=3.4415, top1=31.85%, top5=57.04%]
# Epoch   5/20 | train_loss=3.4978 train_acc=30.62% | val_loss=3.4415 val_acc=31.85% val_top5=57.04% | lr=8.54e-06 peak_mem=1414MB time=51.3s
# Training: 100%|██████████| 1406/1406 [00:49<00:00, 28.35it/s, acc=30.92%, loss=3.4809]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 103.15it/s, loss=3.4337, top1=32.07%, top5=56.98%]
# Epoch   6/20 | train_loss=3.4809 train_acc=30.92% | val_loss=3.4337 val_acc=32.07% val_top5=56.98% | lr=7.94e-06 peak_mem=1414MB time=51.2s
# Training: 100%|██████████| 1406/1406 [00:49<00:00, 28.33it/s, acc=30.88%, loss=3.4770]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 103.96it/s, loss=3.4364, top1=32.07%, top5=57.27%]
# Epoch   7/20 | train_loss=3.4770 train_acc=30.88% | val_loss=3.4364 val_acc=32.07% val_top5=57.27% | lr=7.27e-06 peak_mem=1414MB time=51.2s
# Training: 100%|██████████| 1406/1406 [00:49<00:00, 28.37it/s, acc=30.92%, loss=3.4722]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 101.25it/s, loss=3.4240, top1=32.06%, top5=57.27%]
# Epoch   8/20 | train_loss=3.4722 train_acc=30.92% | val_loss=3.4240 val_acc=32.06% val_top5=57.27% | lr=6.55e-06 peak_mem=1414MB time=51.2s
# Early stopping at epoch 8
#
# ================= Run Summary =================
# Model          : qat_alexnet_tv
# Epochs         : 8
# Best Val Top-1 : 32.20%
# Best Val Top-5 : 57.11%
# Final Val Top-1: 32.06%
# Final Val Top-5: 57.27%
# Best Val Loss  : 3.4379
# Total Time     : 00:06:58
# ===============================================
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_val_acc</td><td>▁█</td></tr><tr><td>epoch_time_s</td><td>█▂▃▁▂▁▁▁</td></tr><tr><td>lr</td><td>██▇▆▅▄▂▁</td></tr><tr><td>peak_gpu_mem_mb</td><td>▁▁▁▁▁▁▁▁</td></tr><tr><td>train_acc</td><td>▁▃▂▃▅███</td></tr><tr><td>train_loss</td><td>█▆▆▅▅▂▂▁</td></tr><tr><td>val_acc</td><td>▂▁█▆▄▆▆▆</td></tr><tr><td>val_loss</td><td>█▃▇▆█▅▆▁</td></tr><tr><td>val_top5</td><td>▁▄▄█▃▃▆▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_acc</td><td>32.2</td></tr><tr><td>epoch_time_s</td><td>51.16254</td></tr><tr><td>lr</td><td>1e-05</td></tr><tr><td>peak_gpu_mem_mb</td><td>1414.00244</td></tr><tr><td>train_acc</td><td>30.92105</td></tr><tr><td>train_loss</td><td>3.47224</td></tr><tr><td>val_acc</td><td>32.06</td></tr><tr><td>val_loss</td><td>3.42404</td></tr><tr><td>val_top5</td><td>57.27</td></tr></table><br/></div></div>
# You can sync this run to the cloud by running:<br><code>wandb sync /home/rafael/Documents/alexnet_rafael/notebooks/wandb/offline-run-20260630_115603-kcn6r9ke<code>
# Find logs at: <code>./wandb/offline-run-20260630_115603-kcn6r9ke/logs</code>
# ========================================================================
# QAT fine-tuning: vgg_style
# ========================================================================
# /home/rafael/Documents/alexnet_rafael/.venv/lib/python3.12/site-packages/torch/ao/quantization/observer.py:229: UserWarning: Please use quant_min and quant_max to specify the range for observers.                     reduce_range will be deprecated in a future release of PyTorch.
#   warnings.warn(
# Tracking run with wandb version 0.28.0
# W&B syncing is set to <code>`offline`<code> in this directory. Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.<br>Run data is saved locally in <code>/home/rafael/Documents/alexnet_rafael/notebooks/wandb/offline-run-20260630_120302-508uu8h0</code><br>View this run in the terminal with <code>`wandb leet`<code>
# Training: 100%|██████████| 1406/1406 [00:40<00:00, 35.09it/s, acc=62.91%, loss=2.2127]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 78.58it/s, loss=2.7559, top1=51.01%, top5=75.36%]
# wandb: WARNING Symlinked 1 file into the W&B run directory; call wandb.save again to sync new files.
# Epoch   1/20 | train_loss=2.2127 train_acc=62.91% | val_loss=2.7559 val_acc=51.01% val_top5=75.36% | lr=9.94e-06 peak_mem=715MB time=42.1s
# Training: 100%|██████████| 1406/1406 [00:40<00:00, 34.69it/s, acc=63.37%, loss=2.1957]
# Validation: 100%|██████████| 157/157 [00:02<00:00, 77.23it/s, loss=2.7497, top1=51.19%, top5=75.48%]
# Epoch   2/20 | train_loss=2.1957 train_acc=63.37% | val_loss=2.7497 val_acc=51.19% val_top5=75.48% | lr=9.76e-06 peak_mem=715MB time=42.6s
# Training: 100%|██████████| 1406/1406 [00:40<00:00, 34.68it/s, acc=63.43%, loss=2.1993]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 80.35it/s, loss=2.7506, top1=51.04%, top5=75.27%]
# Epoch   3/20 | train_loss=2.1993 train_acc=63.43% | val_loss=2.7506 val_acc=51.04% val_top5=75.27% | lr=9.46e-06 peak_mem=715MB time=42.6s
# Training: 100%|██████████| 1406/1406 [00:40<00:00, 34.76it/s, acc=63.71%, loss=2.1886]
# Validation: 100%|██████████| 157/157 [00:02<00:00, 73.46it/s, loss=2.7558, top1=50.97%, top5=75.29%]
# Epoch   4/20 | train_loss=2.1886 train_acc=63.71% | val_loss=2.7558 val_acc=50.97% val_top5=75.29% | lr=9.05e-06 peak_mem=715MB time=42.7s
# Training: 100%|██████████| 1406/1406 [00:40<00:00, 34.64it/s, acc=63.45%, loss=2.1912]
# Validation: 100%|██████████| 157/157 [00:02<00:00, 75.78it/s, loss=2.7474, top1=51.12%, top5=75.31%]
# Epoch   5/20 | train_loss=2.1912 train_acc=63.45% | val_loss=2.7474 val_acc=51.12% val_top5=75.31% | lr=8.54e-06 peak_mem=715MB time=42.7s
# Training: 100%|██████████| 1406/1406 [00:40<00:00, 34.86it/s, acc=63.73%, loss=2.1852]
# Validation: 100%|██████████| 157/157 [00:02<00:00, 77.39it/s, loss=2.7169, top1=51.70%, top5=76.05%]
# Epoch   6/20 | train_loss=2.1852 train_acc=63.73% | val_loss=2.7169 val_acc=51.70% val_top5=76.05% | lr=7.94e-06 peak_mem=715MB time=42.4s
# Training: 100%|██████████| 1406/1406 [00:40<00:00, 35.00it/s, acc=63.81%, loss=2.1804]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 81.39it/s, loss=2.7183, top1=51.86%, top5=76.01%]
# Epoch   7/20 | train_loss=2.1804 train_acc=63.81% | val_loss=2.7183 val_acc=51.86% val_top5=76.01% | lr=7.27e-06 peak_mem=715MB time=42.2s
# Training: 100%|██████████| 1406/1406 [00:39<00:00, 35.36it/s, acc=63.73%, loss=2.1835]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 82.23it/s, loss=2.7176, top1=51.84%, top5=76.01%]
# Epoch   8/20 | train_loss=2.1835 train_acc=63.73% | val_loss=2.7176 val_acc=51.84% val_top5=76.01% | lr=6.55e-06 peak_mem=715MB time=41.7s
# Training: 100%|██████████| 1406/1406 [00:41<00:00, 34.22it/s, acc=63.81%, loss=2.1825]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 81.75it/s, loss=2.7307, top1=51.43%, top5=75.81%]
# Epoch   9/20 | train_loss=2.1825 train_acc=63.81% | val_loss=2.7307 val_acc=51.43% val_top5=75.81% | lr=5.78e-06 peak_mem=715MB time=43.1s
# Training: 100%|██████████| 1406/1406 [00:39<00:00, 35.25it/s, acc=63.83%, loss=2.1809]
# Validation: 100%|██████████| 157/157 [00:01<00:00, 82.10it/s, loss=2.7331, top1=51.57%, top5=75.77%]
# Epoch  10/20 | train_loss=2.1809 train_acc=63.83% | val_loss=2.7331 val_acc=51.57% val_top5=75.77% | lr=5.00e-06 peak_mem=715MB time=41.9s
# Training: 100%|██████████| 1406/1406 [00:40<00:00, 34.93it/s, acc=63.95%, loss=2.1777]
# Validation: 100%|██████████| 157/157 [00:02<00:00, 75.28it/s, loss=2.7259, top1=51.61%, top5=75.88%]
# Epoch  11/20 | train_loss=2.1777 train_acc=63.95% | val_loss=2.7259 val_acc=51.61% val_top5=75.88% | lr=4.22e-06 peak_mem=715MB time=42.4s
# Training: 100%|██████████| 1406/1406 [00:41<00:00, 33.82it/s, acc=64.12%, loss=2.1716]
# Validation: 100%|██████████| 157/157 [00:02<00:00, 73.03it/s, loss=2.7357, top1=51.29%, top5=75.42%]
# Epoch  12/20 | train_loss=2.1716 train_acc=64.12% | val_loss=2.7357 val_acc=51.29% val_top5=75.42% | lr=3.45e-06 peak_mem=715MB time=43.8s
# Early stopping at epoch 12
#
# ================= Run Summary =================
# Model          : qat_vgg_style
# Epochs         : 12
# Best Val Top-1 : 51.86%
# Best Val Top-5 : 76.01%
# Final Val Top-1: 51.29%
# Final Val Top-5: 75.42%
# Best Val Loss  : 2.7183
# Total Time     : 00:08:31
# ===============================================
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>best_val_acc</td><td>▁▂▇█</td></tr><tr><td>epoch_time_s</td><td>▂▄▄▄▄▃▂▁▆▁▃█</td></tr><tr><td>lr</td><td>██▇▇▆▆▅▄▄▃▂▁</td></tr><tr><td>peak_gpu_mem_mb</td><td>▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_acc</td><td>▁▄▄▆▄▆▆▆▆▆▇█</td></tr><tr><td>train_loss</td><td>█▅▆▄▄▃▃▃▃▃▂▁</td></tr><tr><td>val_acc</td><td>▁▃▂▁▂▇██▅▆▆▄</td></tr><tr><td>val_loss</td><td>█▇▇█▆▁▁▁▃▄▃▄</td></tr><tr><td>val_top5</td><td>▂▃▁▁▁███▆▅▆▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>best_val_acc</td><td>51.86</td></tr><tr><td>epoch_time_s</td><td>43.81784</td></tr><tr><td>lr</td><td>0.0</td></tr><tr><td>peak_gpu_mem_mb</td><td>715.15625</td></tr><tr><td>train_acc</td><td>64.11584</td></tr><tr><td>train_loss</td><td>2.1716</td></tr><tr><td>val_acc</td><td>51.29</td></tr><tr><td>val_loss</td><td>2.73574</td></tr><tr><td>val_top5</td><td>75.42</td></tr></table><br/></div></div>
# You can sync this run to the cloud by running:<br><code>wandb sync /home/rafael/Documents/alexnet_rafael/notebooks/wandb/offline-run-20260630_120302-508uu8h0<code>
# Find logs at: <code>./wandb/offline-run-20260630_120302-508uu8h0/logs</code>
# Skipping QAT for resnet18_tv (QAT_SKIP).
# Skipping QAT for mobilenetv2 (QAT_SKIP).
#
# QAT training complete.

# %% [markdown]
# ## 7. INT8 conversion & CPU evaluation
#
# `torch.ao.quantization.convert` materialises true quantised ops and must run on CPU.

# %%
val_loader_cpu = torch.utils.data.DataLoader(
    val_ds, batch_size=data_cfg.batch_size, shuffle=False, num_workers=0, pin_memory=False,
)
cpu_device = torch.device("cpu")

int8_models = {name: convert_to_int8(m.cpu().eval()) for name, m in qat_models.items()}

for name, m in int8_models.items():
    torch.save(m.state_dict(), SAVE_DIR / f"{name}.pth")
    compress_checkpoint(SAVE_DIR / f"{name}.pth")
print("INT8 conversion done.")

int8_metrics = {}
for name, m in int8_models.items():
    dummy_cfg = replace(fp32_cfg, use_amp=False)
    trainer = Trainer(
        m.cpu().eval(), val_loader_cpu, val_loader_cpu, dummy_cfg,
        cpu_device, SAVE_DIR, name, num_classes=data_cfg.num_classes,
    )
    metrics = trainer.evaluate(topk=(1, 5))
    int8_metrics[name] = metrics
    print(f"{name:22s} | loss={metrics['loss']:.4f} | top1={metrics['top1']:.2f}% | top5={metrics['top5']:.2f}%")

# %% [markdown]
# ## 8. FP32 evaluation — reload best checkpoints

# %%
CTORS = {
    "alexnet_tv":  AlexNetTV,
    "vgg_style":   VGGStyleCNN,
    "resnet18_tv": ResNet18TV,
    "mobilenetv2": MobileNetV2TV,
}

fp32_best = {name: load_best_model(name, ctor, SAVE_DIR, device) for name, ctor in CTORS.items()}

fp32_metrics = {}
for name, m in fp32_best.items():
    dummy_cfg = replace(fp32_cfg, use_amp=False)
    trainer = Trainer(
        m, train_loader, val_loader, dummy_cfg,
        device, SAVE_DIR, name, num_classes=data_cfg.num_classes,
    )
    metrics = trainer.evaluate(topk=(1, 5))
    fp32_metrics[name] = metrics
    print(f"{name:22s} | loss={metrics['loss']:.4f} | top1={metrics['top1']:.2f}% | top5={metrics['top5']:.2f}%")
# Out:
# alexnet_tv             | loss=2.9938 | top1=32.89% | top5=58.22%
# vgg_style              | loss=2.0700 | top1=51.81% | top5=75.88%
# resnet18_tv            | loss=1.9659 | top1=53.91% | top5=77.80%
# mobilenetv2            | loss=1.7545 | top1=58.00% | top5=81.51%

# %% [markdown]
# ## 9. Final comparison table

# %%
rows = []

for name, m in fp32_best.items():
    info = torchinfo.summary(m, input_size=(1, 3, data_cfg.img_size, data_cfg.img_size), verbose=0)
    rows.append({
        "model": name, "precision": "FP32",
        "top1_%": fp32_metrics[name]["top1"],
        "top5_%": fp32_metrics[name]["top5"],
        "loss":   fp32_metrics[name]["loss"],
        "params_M": info.total_params / 1e6,
        "size_MB":  disk_mb(SAVE_DIR / f"{name}_best.pth"),
    })

for name, m in int8_models.items():
    info = torchinfo.summary(fp32_best[name], input_size=(1, 3, data_cfg.img_size, data_cfg.img_size), verbose=0)
    rows.append({
        "model": f"{name}_INT8", "precision": "INT8",
        "top1_%": int8_metrics[name]["top1"],
        "top5_%": int8_metrics[name]["top5"],
        "loss":   int8_metrics[name]["loss"],
        "params_M": info.total_params / 1e6,
        "size_MB":  disk_mb(SAVE_DIR / f"{name}.pth"),
    })

df = build_comparison_table(rows)
df.to_csv(RESULTS_DIR / "final_comparison.csv", index=False)
df
# Out:
#              model precision     top1_%     top5_%      loss   params_M  \
# 0      mobilenetv2      FP32  57.995582  81.514984  1.754526   2.480072
# 1      resnet18_tv      FP32  53.913635  77.797484  1.965944  11.279112
# 2        vgg_style      FP32  51.814806  75.881696  2.070006   2.405288
# 3       alexnet_tv      FP32  32.887921  58.219731  2.993848  57.823240
# 4   vgg_style_INT8      INT8  51.188743  75.520074  2.093931   2.405288
# 5  alexnet_tv_INT8      INT8  31.903201  57.237488  3.041804  57.823240
#
#       size_MB
# 0   28.751925
# 1  129.208681
# 2   27.584812
# 3  661.754141
# 4    2.376703
# 5   55.332613

# %%
import json as _json

# --- Benchmark FP32 models (GPU) ---
fp32_benchmarks = {}
for name, m in fp32_best.items():
    dummy_cfg = replace(fp32_cfg, use_amp=False)
    t = Trainer(m, train_loader, val_loader, dummy_cfg, device, SAVE_DIR, name,
                num_classes=data_cfg.num_classes)
    fp32_benchmarks[name] = t.benchmark()
    print(f"{name:22s} FP32 | {fp32_benchmarks[name]['latency_ms_per_image']:.3f} ms/img")

# --- Benchmark INT8 models (CPU) ---
int8_benchmarks = {}
for name, m in int8_models.items():
    dummy_cfg = replace(fp32_cfg, use_amp=False)
    t = Trainer(m.cpu().eval(), val_loader_cpu, val_loader_cpu, dummy_cfg, cpu_device, SAVE_DIR, name,
                num_classes=data_cfg.num_classes)
    int8_benchmarks[name] = t.benchmark(warmup=50)
    print(f"{name:22s} INT8 | {int8_benchmarks[name]['latency_ms_per_image']:.3f} ms/img")

# --- FLOPs ---
fp32_flops = {}
for name, m in fp32_best.items():
    fp32_flops[name] = compute_flops(m.cpu().eval())
    print(f"{name:22s} | {fp32_flops[name]['macs']/1e9:.3f} GMACs")

# --- Per-model summary JSONs ---
RESULTS_DIR.mkdir(parents=True, exist_ok=True)
for name in fp32_best:
    compress_checkpoint(SAVE_DIR / f"{name}_best.pth")
    info = torchinfo.summary(fp32_best[name], input_size=(1, 3, data_cfg.img_size, data_cfg.img_size), verbose=0)
    summary = make_run_summary(
        name=name,
        mode="fp32+qat+int8",
        fit_results=fp32_training_results.get(name, {}),
        fp32_eval=fp32_metrics[name],
        params_m=info.total_params / 1e6,
        fp32_size_mb=disk_mb(SAVE_DIR / f"{name}_best.pth"),
        int8_size_mb=disk_mb(SAVE_DIR / f"{name}.pth"),
        fp32_benchmark=fp32_benchmarks[name],
        flops_results=fp32_flops[name],
        int8_eval=int8_metrics.get(name),
        int8_benchmark=int8_benchmarks.get(name),
        fp32_gzip_mb=gzip_mb(SAVE_DIR / f"{name}_best.pth"),
        int8_gzip_mb=gzip_mb(SAVE_DIR / f"{name}.pth"),
    )
    out = RESULTS_DIR / f"{name}_summary.json"
    with open(out, "w") as f:
        _json.dump(summary, f, indent=2, default=str)
    print(f"Saved: {out.name}")

# %%
print("=" * 72)
print("RANKING BY TOP-1 ACCURACY (all precisions)")
print("=" * 72)
ranked = df.sort_values("top1_%", ascending=False).reset_index(drop=True)
for i, row in ranked.iterrows():
    print(f"{i+1:2d}. {row['model']:26s} [{row['precision']}] | "
          f"top1={row['top1_%']:6.2f}% | top5={row['top5_%']:6.2f}% | "
          f"params={row['params_M']:6.2f}M | size={row['size_MB']:6.2f}MB")
# Out:
# ========================================================================
# RANKING BY TOP-1 ACCURACY (all precisions)
# ========================================================================
#  1. mobilenetv2                [FP32] | top1= 58.00% | top5= 81.51% | params=  2.48M | size= 28.75MB
#  2. resnet18_tv                [FP32] | top1= 53.91% | top5= 77.80% | params= 11.28M | size=129.21MB
#  3. vgg_style                  [FP32] | top1= 51.81% | top5= 75.88% | params=  2.41M | size= 27.58MB
#  4. vgg_style_INT8             [INT8] | top1= 51.19% | top5= 75.52% | params=  2.41M | size=  2.38MB
#  5. alexnet_tv                 [FP32] | top1= 32.89% | top5= 58.22% | params= 57.82M | size=661.75MB
#  6. alexnet_tv_INT8            [INT8] | top1= 31.90% | top5= 57.24% | params= 57.82M | size= 55.33MB

# %% [markdown]
# ## 10. Persist experiment summary

# %%
create_results_summary(
    results={
        "fp32_metrics": fp32_metrics,
        "int8_metrics": int8_metrics,
        "fp32_training_results": fp32_training_results,
        "qat_training_results": qat_training_results,
    },
    config=asdict(fp32_cfg),
    output_path=RESULTS_DIR / "experiment_summary.json",
)

# %% [markdown]
# ## W&B — syncing offline runs
#
# All runs were saved locally with `mode="offline"`. Two run groups are tracked:
# - **`fp32-baselines-phase1`** — one run per architecture, FP32 training
# - **`int8-baselines-phase1`** — one run per architecture (excl. `resnet18_tv`), QAT fine-tuning
#
# When ready, sync to the W&B dashboard from a terminal:
#
# ```bash
# wandb sync --sync-all
# ```
